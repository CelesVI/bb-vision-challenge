# %%
#Import all necesaries libraries
from selenium import webdriver
import pandas as pd
import time

# %%
#Get url to scrap all the series.
url_series = "https://www.starz.com/ar/es/view-all/blocks/1523514"

# %%
#Create an instance of webdriver to scrap.
#It uses an chrome driver located on root path.
driver = webdriver.Chrome(executable_path = r'chromedriver.exe')

# %%
#Set url to the drive. Wait 8 seconds to load all the data from url.
driver.get(url_series)
time.sleep(8)

# %%
#The movies links are located on view-all-container class.
#Get the view-all-scrollable object.
html = driver.find_element_by_class_name('view-all-container')

# %%
html
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="937c4bd4f87318c702b5663a66f8bbf1", element="ed7aa714-c011-4874-8f2e-b063195431ae")>

# %%
#Create an empty list to get all links in html variable.
lista_links = []

# %%
#Iterate throught xpath looking for href attribute.
for link in driver.find_elements_by_xpath('.//a'):
    lista_links.append(link.get_attribute('href'))

# %%
lista_links
# Out:
# ['https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/signup',
#  None,
#  None,
#  None,
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series/the-borgias/61183',
#  'https://www.starz.com/ar/es/series/the-borgias/61183',
#  'https://www.starz.com/ar/es/series/the-white-queen/18124',
#  'https://www.starz.com/ar/es/series/the-white-queen/18124',
#  'https://www.starz.com/ar/es/series/sweetbitter/37699',
#  'https://www.starz.com/ar/es/series/sweetbitter/37699',
#  'https://www.starz.com/ar/es/series/reign/63571',
#  'https://www.starz.com/ar/es/series/reign/63571',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-white-princess/30887',
#  'https://www.starz.com/ar/es/series/the-white-princess/30887',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/power/21220',
#  'https://www.starz.com/ar/es/series/power/21220',
#  'https://www.starz.com/ar/es/series/houdini/45824',
#  'https://www.starz.com/ar/es/series/houdini/45824',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/black-sails/19568',
#  'https://www.starz.com/ar/es/series/black-sails/19568',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/motherfatherson/44758',
#  'https://www.starz.com/ar/es/series/motherfatherson/44758',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/vida/37707',
#  'https://www.starz.com/ar/es/series/vida/37707',
#  'https://www.starz.com/ar/es/series/dublin-murders/45426',
#  'https://www.starz.com/ar/es/series/dublin-murders/45426',
#  'https://www.starz.com/ar/es/series/howards-end/37269',
#  'https://www.starz.com/ar/es/series/howards-end/37269',
#  'https://www.starz.com/ar/es/series/the-capture/57770',
#  'https://www.starz.com/ar/es/series/the-capture/57770',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/luther/45048',
#  'https://www.starz.com/ar/es/series/luther/45048',
#  'https://www.starz.com/ar/es/series/sr-mercedes/45919',
#  'https://www.starz.com/ar/es/series/sr-mercedes/45919',
#  'https://www.starz.com/ar/es/series/instinto-animal/56898',
#  'https://www.starz.com/ar/es/series/instinto-animal/56898',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/spartacus/5972',
#  'https://www.starz.com/ar/es/series/spartacus/5972',
#  'https://www.starz.com/ar/es/series/the-rook/44140',
#  'https://www.starz.com/ar/es/series/the-rook/44140',
#  'https://www.starz.com/ar/es/series/the-name-of-the-rose/45429',
#  'https://www.starz.com/ar/es/series/the-name-of-the-rose/45429',
#  'https://www.starz.com/ar/es/series/the-royals/45706',
#  'https://www.starz.com/ar/es/series/the-royals/45706',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/penny-dreadful/61184',
#  'https://www.starz.com/ar/es/series/penny-dreadful/61184',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/los-miserables/46038',
#  'https://www.starz.com/ar/es/series/los-miserables/46038',
#  'https://www.starz.com/ar/es/series/blue-mountain-state/46152',
#  'https://www.starz.com/ar/es/series/blue-mountain-state/46152',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/high-fidelity/60255',
#  'https://www.starz.com/ar/es/series/high-fidelity/60255',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/boss/30888',
#  'https://www.starz.com/ar/es/series/boss/30888',
#  'https://www.starz.com/ar/es/series/wrong-man/38184',
#  'https://www.starz.com/ar/es/series/wrong-man/38184',
#  'https://www.starz.com/ar/es/series/now-apocalypse/43571',
#  'https://www.starz.com/ar/es/series/now-apocalypse/43571',
#  'https://www.starz.com/ar/es/series/the-dresden-files/45616',
#  'https://www.starz.com/ar/es/series/the-dresden-files/45616',
#  'https://www.starz.com/ar/es/series/and-then-there-were-none/45929',
#  'https://www.starz.com/ar/es/series/and-then-there-were-none/45929',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/das-boot/45955',
#  'https://www.starz.com/ar/es/series/das-boot/45955',
#  'https://www.starz.com/ar/es/series/wolf-creek/46155',
#  'https://www.starz.com/ar/es/series/wolf-creek/46155',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/america-to-me/38818',
#  'https://www.starz.com/ar/es/series/america-to-me/38818',
#  'https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040',
#  'https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040',
#  'https://www.starz.com/ar/es/series/leavenworth/45100',
#  'https://www.starz.com/ar/es/series/leavenworth/45100',
#  'https://www.starz.com/ar/es/series/chasing-life/45516',
#  'https://www.starz.com/ar/es/series/chasing-life/45516',
#  'https://www.starz.com/ar/es/series/the-kill-point/45612',
#  'https://www.starz.com/ar/es/series/the-kill-point/45612',
#  'https://www.starz.com/ar/es/series/the-little-drummer-girl/45715',
#  'https://www.starz.com/ar/es/series/the-little-drummer-girl/45715',
#  'https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716',
#  'https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716',
#  'https://www.starz.com/ar/es/series/rosemarys-baby/45825',
#  'https://www.starz.com/ar/es/series/rosemarys-baby/45825',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/manhunt-deadly-games/59063',
#  'https://www.starz.com/ar/es/series/manhunt-deadly-games/59063',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/browse/originals',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/signup',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/faq',
#  'https://www.starz.com/ar/es/login/activate',
#  'https://www.starz.com/ar/es/supporteddevices',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/browse/genre/acci%C3%B3n',
#  'https://www.starz.com/ar/es/browse/genre/comedias',
#  'https://www.starz.com/ar/es/browse/genre/cr%C3%ADmenes-reales',
#  'https://www.starz.com/ar/es/browse/genre/de-terror',
#  'https://www.starz.com/ar/es/browse/genre/dramas',
#  'https://www.starz.com/ar/es/browse/genre/dramas-de-%C3%A9poca',
#  'https://www.starz.com/ar/es/browse/genre/nuevos-lanzamientos',
#  'https://www.starz.com/ar/es/browse/genre/rom%C3%A1nticas',
#  'https://www.starz.com/ar/es/browse/genre/series-dram%C3%A1ticas-de-relaciones',
#  'https://www.starz.com/ar/es/browse/genre/series-policiales',
#  'https://www.starz.com/ar/es/browse/genre/si-te-gusta-the-great',
#  'https://www.starz.com/ar/es/browse/genre/thriller',
#  'https://www.starz.com/ar/es/browse/genre/%C3%BAltima-oportunidad']

# %%
#Filter none objects.
lista_links = list(filter(None, lista_links))

# %%
lista_links
# Out:
# ['https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/signup',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series/the-borgias/61183',
#  'https://www.starz.com/ar/es/series/the-borgias/61183',
#  'https://www.starz.com/ar/es/series/the-white-queen/18124',
#  'https://www.starz.com/ar/es/series/the-white-queen/18124',
#  'https://www.starz.com/ar/es/series/sweetbitter/37699',
#  'https://www.starz.com/ar/es/series/sweetbitter/37699',
#  'https://www.starz.com/ar/es/series/reign/63571',
#  'https://www.starz.com/ar/es/series/reign/63571',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-white-princess/30887',
#  'https://www.starz.com/ar/es/series/the-white-princess/30887',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/power/21220',
#  'https://www.starz.com/ar/es/series/power/21220',
#  'https://www.starz.com/ar/es/series/houdini/45824',
#  'https://www.starz.com/ar/es/series/houdini/45824',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/black-sails/19568',
#  'https://www.starz.com/ar/es/series/black-sails/19568',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/motherfatherson/44758',
#  'https://www.starz.com/ar/es/series/motherfatherson/44758',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/vida/37707',
#  'https://www.starz.com/ar/es/series/vida/37707',
#  'https://www.starz.com/ar/es/series/dublin-murders/45426',
#  'https://www.starz.com/ar/es/series/dublin-murders/45426',
#  'https://www.starz.com/ar/es/series/howards-end/37269',
#  'https://www.starz.com/ar/es/series/howards-end/37269',
#  'https://www.starz.com/ar/es/series/the-capture/57770',
#  'https://www.starz.com/ar/es/series/the-capture/57770',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/luther/45048',
#  'https://www.starz.com/ar/es/series/luther/45048',
#  'https://www.starz.com/ar/es/series/sr-mercedes/45919',
#  'https://www.starz.com/ar/es/series/sr-mercedes/45919',
#  'https://www.starz.com/ar/es/series/instinto-animal/56898',
#  'https://www.starz.com/ar/es/series/instinto-animal/56898',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/spartacus/5972',
#  'https://www.starz.com/ar/es/series/spartacus/5972',
#  'https://www.starz.com/ar/es/series/the-rook/44140',
#  'https://www.starz.com/ar/es/series/the-rook/44140',
#  'https://www.starz.com/ar/es/series/the-name-of-the-rose/45429',
#  'https://www.starz.com/ar/es/series/the-name-of-the-rose/45429',
#  'https://www.starz.com/ar/es/series/the-royals/45706',
#  'https://www.starz.com/ar/es/series/the-royals/45706',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/penny-dreadful/61184',
#  'https://www.starz.com/ar/es/series/penny-dreadful/61184',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/los-miserables/46038',
#  'https://www.starz.com/ar/es/series/los-miserables/46038',
#  'https://www.starz.com/ar/es/series/blue-mountain-state/46152',
#  'https://www.starz.com/ar/es/series/blue-mountain-state/46152',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/high-fidelity/60255',
#  'https://www.starz.com/ar/es/series/high-fidelity/60255',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/boss/30888',
#  'https://www.starz.com/ar/es/series/boss/30888',
#  'https://www.starz.com/ar/es/series/wrong-man/38184',
#  'https://www.starz.com/ar/es/series/wrong-man/38184',
#  'https://www.starz.com/ar/es/series/now-apocalypse/43571',
#  'https://www.starz.com/ar/es/series/now-apocalypse/43571',
#  'https://www.starz.com/ar/es/series/the-dresden-files/45616',
#  'https://www.starz.com/ar/es/series/the-dresden-files/45616',
#  'https://www.starz.com/ar/es/series/and-then-there-were-none/45929',
#  'https://www.starz.com/ar/es/series/and-then-there-were-none/45929',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/das-boot/45955',
#  'https://www.starz.com/ar/es/series/das-boot/45955',
#  'https://www.starz.com/ar/es/series/wolf-creek/46155',
#  'https://www.starz.com/ar/es/series/wolf-creek/46155',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/america-to-me/38818',
#  'https://www.starz.com/ar/es/series/america-to-me/38818',
#  'https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040',
#  'https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040',
#  'https://www.starz.com/ar/es/series/leavenworth/45100',
#  'https://www.starz.com/ar/es/series/leavenworth/45100',
#  'https://www.starz.com/ar/es/series/chasing-life/45516',
#  'https://www.starz.com/ar/es/series/chasing-life/45516',
#  'https://www.starz.com/ar/es/series/the-kill-point/45612',
#  'https://www.starz.com/ar/es/series/the-kill-point/45612',
#  'https://www.starz.com/ar/es/series/the-little-drummer-girl/45715',
#  'https://www.starz.com/ar/es/series/the-little-drummer-girl/45715',
#  'https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716',
#  'https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716',
#  'https://www.starz.com/ar/es/series/rosemarys-baby/45825',
#  'https://www.starz.com/ar/es/series/rosemarys-baby/45825',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/manhunt-deadly-games/59063',
#  'https://www.starz.com/ar/es/series/manhunt-deadly-games/59063',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/browse/originals',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/signup',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/faq',
#  'https://www.starz.com/ar/es/login/activate',
#  'https://www.starz.com/ar/es/supporteddevices',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/browse/genre/acci%C3%B3n',
#  'https://www.starz.com/ar/es/browse/genre/comedias',
#  'https://www.starz.com/ar/es/browse/genre/cr%C3%ADmenes-reales',
#  'https://www.starz.com/ar/es/browse/genre/de-terror',
#  'https://www.starz.com/ar/es/browse/genre/dramas',
#  'https://www.starz.com/ar/es/browse/genre/dramas-de-%C3%A9poca',
#  'https://www.starz.com/ar/es/browse/genre/nuevos-lanzamientos',
#  'https://www.starz.com/ar/es/browse/genre/rom%C3%A1nticas',
#  'https://www.starz.com/ar/es/browse/genre/series-dram%C3%A1ticas-de-relaciones',
#  'https://www.starz.com/ar/es/browse/genre/series-policiales',
#  'https://www.starz.com/ar/es/browse/genre/si-te-gusta-the-great',
#  'https://www.starz.com/ar/es/browse/genre/thriller',
#  'https://www.starz.com/ar/es/browse/genre/%C3%BAltima-oportunidad']

# %%
#Series links have '/series/' string on their urls.
#Create a varible to filter later.
movies_match = '/series/'

# %%
#List comprehension to filter by the previous string.
#Convert to set to remove duplicates.
#Then, convert to list again to iterate.
#Now, we have the links of all series.
useful_links = list(set([link for link in lista_links if movies_match in link]))

# %%
useful_links
# Out:
# ['https://www.starz.com/ar/es/series/howards-end/37269',
#  'https://www.starz.com/ar/es/series/vida/37707',
#  'https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040',
#  'https://www.starz.com/ar/es/series/blue-mountain-state/46152',
#  'https://www.starz.com/ar/es/series/sr-mercedes/45919',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/now-apocalypse/43571',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/the-royals/45706',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/the-white-princess/30887',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/wrong-man/38184',
#  'https://www.starz.com/ar/es/series/sweetbitter/37699',
#  'https://www.starz.com/ar/es/series/chasing-life/45516',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/power/21220',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/instinto-animal/56898',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-white-queen/18124',
#  'https://www.starz.com/ar/es/series/the-dresden-files/45616',
#  'https://www.starz.com/ar/es/series/the-rook/44140',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/das-boot/45955',
#  'https://www.starz.com/ar/es/series/america-to-me/38818',
#  'https://www.starz.com/ar/es/series/the-little-drummer-girl/45715',
#  'https://www.starz.com/ar/es/series/the-name-of-the-rose/45429',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/dublin-murders/45426',
#  'https://www.starz.com/ar/es/series/black-sails/19568',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/high-fidelity/60255',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/the-capture/57770',
#  'https://www.starz.com/ar/es/series/manhunt-deadly-games/59063',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/leavenworth/45100',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/luther/45048',
#  'https://www.starz.com/ar/es/series/los-miserables/46038',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/and-then-there-were-none/45929',
#  'https://www.starz.com/ar/es/series/step-up/62777',
#  'https://www.starz.com/ar/es/series/houdini/45824',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/motherfatherson/44758',
#  'https://www.starz.com/ar/es/series/the-kill-point/45612',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/spartacus/5972',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/boss/30888',
#  'https://www.starz.com/ar/es/series/penny-dreadful/61184',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/rosemarys-baby/45825',
#  'https://www.starz.com/ar/es/series/the-borgias/61183',
#  'https://www.starz.com/ar/es/series/reign/63571',
#  'https://www.starz.com/ar/es/series/wolf-creek/46155',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195']

# %%
#Empty list to save the collection of dictionaries.
#Dictionary to save metada from series and append it on the list.
lista_series = []

# %%
#Iterate throught series links.
#Get data from url and wait 5 second to get all data from the url.
#Get data from xpath and save it.
#Then, create a dictionary to store metadata and append it on the list.
for i in useful_links:
    print(i)
    driver.get(i)
    time.sleep(4)
    titulo = driver.find_element_by_xpath('.//*[@id="seriesDetailsH1"]').text
    clasificacion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[1]').text
    episodios = driver.find_element_by_xpath('./html/body/starz-root/div/div[1]/section/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[1]').text +' '+ driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[3]').text
    genero = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[3]').text
    anio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[4]').text
    sinopsis = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/div[2]').text[:-8]
    diccionario_series = {
        'titulo':titulo,
        'clasificacion':clasificacion,
        'episodios':episodios,
        'genero':genero,
        'año':anio,
        'sinopsis':sinopsis
    }
    lista_series.append(diccionario_series)
print("******Fin******")
'''driver.get(useful_links[:-1])
time.sleep(4)
titulo = driver.find_element_by_xpath('.//*[@id="seriesDetailsH1"]').text
clasificacion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[1]').text
episodios = driver.find_element_by_xpath('./html/body/starz-root/div/div[1]/section/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[1]').text +' '+ driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[3]').text
genero = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[3]').text
anio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[4]').text
sinopsis = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/div[2]').text[:-8]
diccionario_series = {
    'titulo':titulo,
    'clasificacion':clasificacion,
    'episodios':episodios,
    'genero':genero,
    'año':anio,
    'sinopsis':sinopsis
}
lista_series.append(diccionario_series)
print("******Fin******")
'''
# Out:
# https://www.starz.com/ar/es/series/howards-end/37269
# https://www.starz.com/ar/es/series/vida/37707
# https://www.starz.com/ar/es/series/warriors-of-liberty-city/39040
# https://www.starz.com/ar/es/series/blue-mountain-state/46152
# https://www.starz.com/ar/es/series/sr-mercedes/45919
# https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967
# https://www.starz.com/ar/es/series/now-apocalypse/43571
# https://www.starz.com/ar/es/series/hightown/57463
# https://www.starz.com/ar/es/series/the-royals/45706
# https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458
# https://www.starz.com/ar/es/series/the-white-princess/30887
# https://www.starz.com/ar/es/series/power-book-ii-ghost/58002
# https://www.starz.com/ar/es/series/fleming-el-hombre-que-ser%C3%ADa-bond/45716
# https://www.starz.com/ar/es/series/blindspotting/62263
# https://www.starz.com/ar/es/series/malayerba/64882
# https://www.starz.com/ar/es/series/wrong-man/38184
# https://www.starz.com/ar/es/series/sweetbitter/37699
# https://www.starz.com/ar/es/series/chasing-life/45516
# https://www.starz.com/ar/es/series/the-stand/61994
# https://www.starz.com/ar/es/series/power/21220
# https://www.starz.com/ar/es/series/baptiste/45713
# https://www.starz.com/ar/es/series/the-girlfriend-experience/25586
# https://www.starz.com/ar/es/series/heels/60760
# https://www.starz.com/ar/es/series/instinto-animal/56898
# https://www.starz.com/ar/es/series/express/63120
# https://www.starz.com/ar/es/series/the-white-queen/18124
# https://www.starz.com/ar/es/series/the-dresden-files/45616
# https://www.starz.com/ar/es/series/the-rook/44140
# https://www.starz.com/ar/es/series/pennyworth/57149
# https://www.starz.com/ar/es/series/the-attach%C3%A9/62262
# https://www.starz.com/ar/es/series/das-boot/45955
# https://www.starz.com/ar/es/series/america-to-me/38818
# https://www.starz.com/ar/es/series/the-little-drummer-girl/45715
# https://www.starz.com/ar/es/series/the-name-of-the-rose/45429
# https://www.starz.com/ar/es/series/little-birds/62168
# https://www.starz.com/ar/es/series/dublin-murders/45426
# https://www.starz.com/ar/es/series/black-sails/19568
# https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920
# https://www.starz.com/ar/es/series/high-fidelity/60255
# https://www.starz.com/ar/es/series/the-act/46154
# https://www.starz.com/ar/es/series/the-spanish-princess/42457
# https://www.starz.com/ar/es/series/normal-people/60083
# https://www.starz.com/ar/es/series/the-capture/57770
# https://www.starz.com/ar/es/series/manhunt-deadly-games/59063
# https://www.starz.com/ar/es/series/p-valley/46156
# https://www.starz.com/ar/es/series/leavenworth/45100
# https://www.starz.com/ar/es/series/run-the-world/58457
# https://www.starz.com/ar/es/series/no-mans-land/61940
# https://www.starz.com/ar/es/series/luther/45048
# https://www.starz.com/ar/es/series/los-miserables/46038
# https://www.starz.com/ar/es/series/castle-rock/45522
# https://www.starz.com/ar/es/series/the-great/57979
# https://www.starz.com/ar/es/series/and-then-there-were-none/45929
# https://www.starz.com/ar/es/series/step-up/62777
# https://www.starz.com/ar/es/series/houdini/45824
# https://www.starz.com/ar/es/series/power-book-iv-force/62261
# https://www.starz.com/ar/es/series/motherfatherson/44758
# https://www.starz.com/ar/es/series/the-kill-point/45612
# https://www.starz.com/ar/es/series/gangs-of-london/60530
# https://www.starz.com/ar/es/series/the-night-manager/61267
# https://www.starz.com/ar/es/series/spartacus/5972
# https://www.starz.com/ar/es/series/flesh-and-bone/24528
# https://www.starz.com/ar/es/series/boss/30888
# https://www.starz.com/ar/es/series/penny-dreadful/61184
# https://www.starz.com/ar/es/series/dr-death/61268
# https://www.starz.com/ar/es/series/bmf/62264
# https://www.starz.com/ar/es/series/rosemarys-baby/45825
# https://www.starz.com/ar/es/series/the-borgias/61183
# https://www.starz.com/ar/es/series/reign/63571
# https://www.starz.com/ar/es/series/wolf-creek/46155
# https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195
# ******Fin******
# 'driver.get(useful_links[:-1])\ntime.sleep(4)\ntitulo = driver.find_element_by_xpath(\'.//*[@id="seriesDetailsH1"]\').text\nclasificacion = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[1]\').text\nepisodios = driver.find_element_by_xpath(\'./html/body/starz-root/div/div[1]/section/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[1]\').text +\' \'+ driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[2]/span[3]\').text\ngenero = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[3]\').text\nanio = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/ul/li[4]\').text\nsinopsis = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-series-details/div[1]/section/div[1]/div[2]/div[2]\').text[:-8]\ndiccionario_series = {\n    \'titulo\':titulo,\n    \'clasificacion\':clasificacion,\n    \'episodios\':episodios,\n    \'genero\':genero,\n    \'año\':anio,\n    \'sinopsis\':sinopsis\n}\nlista_series.append(diccionario_series)\nprint("******Fin******")\n'

# %%
#Show all the series with their metadata.
lista_series
# Out:
# [{'titulo': 'Howards End',
#   'clasificacion': 'SAM13',
#   'episodios': '4 EPISODIOS',
#   'genero': 'DRAMA, LITERARIA',
#   'año': '2018',
#   'sinopsis': '"Howards End" es la historia de dos hermanas independientes, poco convencionales y los hombres en sus vidas; buscan significado y amor mientras navegan en un mundo q'},
#  {'titulo': 'Vida',
#   'clasificacion': 'SAM16',
#   'episodios': '23 EPISODIOS',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2018 - 2020',
#   'sinopsis': '"Vida" es una serie de media hora que se enfoca en dos hermanas mexico-americanas de lado Este de Los Ángeles que no podrían ser más diferentes ni estar más distanciad'},
#  {'titulo': 'Warriors Of Liberty City',
#   'clasificacion': 'SAM16',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DOCUMENTAL, DEPORTES',
#   'año': '2018',
#   'sinopsis': 'La serie sigue a los Guerreros de Liberty City, un programa de fútbol juvenil. La vida, como el fútbol, es un deporte de contacto, y para los niños, ser un Guerrero es '},
#  {'titulo': 'Blue Mountain State',
#   'clasificacion': 'SAM16',
#   'episodios': '39 EPISODIOS',
#   'genero': 'COMEDIA, DEPORTES',
#   'año': '2010 - 2011',
#   'sinopsis': 'En Blue Mountain State, el campus universitario más pendenciero del país, los atletas aprenden los altibajos de ser unos de los pocos elegidos que son venerados en el'},
#  {'titulo': 'Sr. Mercedes',
#   'clasificacion': 'SAM16',
#   'episodios': '30 EPISODIOS',
#   'genero': 'CRIMEN, SUSPENSO',
#   'año': '2017 - 2019',
#   'sinopsis': 'Un asesino serial demente se burla de un policía retirado con una serie de cartas y correos electrónicos espelu'},
#  {'titulo': 'SEDUCED: INSIDE THE NXIVM CULT',
#   'clasificacion': 'SAM16',
#   'episodios': '4 EPISODIOS',
#   'genero': 'DOCUMENTAL',
#   'año': '2020',
#   'sinopsis': 'Esta docuserie de la directora y productora Cecilia Peck y la productora y editora Inbal Lessner —quienes colaboraron en "Brave Miss World", nominada al Emmy®— sigue '},
#  {'titulo': 'Now Apocalypse',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'COMEDIA, LGBTQ',
#   'año': '2019',
#   'sinopsis': '“Now Apocalypse” se centra en Ulysses y sus amigos, en su búsqueda de amor, sexo y fama mientras intentan navegar la ciudad de Los Ángeles. Los sueños de Ulysses le hac'},
#  {'titulo': 'Hightown',
#   'clasificacion': 'SAM16',
#   'episodios': '19 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2020 - 2021',
#   'sinopsis': 'Ambientada en el bello, pero sombrío, Cabo Cod, esta serie, narra el camino de una mujer para dejar las drogas y el alcohol. Pero todo es eclipsado por una investigación p'},
#  {'titulo': 'The Royals',
#   'clasificacion': 'SAM13',
#   'episodios': '40 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2015 - 2018',
#   'sinopsis': 'The Royals sigue las vidas de una familia real británica ficticia que vive un mundo de opulencia, lujuria, escándalo sexual y tradición regia: un mundo que también tr'},
#  {'titulo': 'Power Book III: Raising Kanan',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2021',
#   'sinopsis': 'Situada al Sur de Jamaica, en Queens, en 1991, "Raising Kanan" es una precuela de la franquicia original "Power". Este drama familiar trata del cambio de edad de Kan'},
#  {'titulo': 'The White Princess',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA, LITERARIA',
#   'año': '2017',
#   'sinopsis': '“The White Princess” representa una turbulenta época de la historia británica desde la visión de las mujeres que encarnan una dura batalla por e'},
#  {'titulo': 'Power Book II: Ghost',
#   'clasificacion': 'SAM16',
#   'episodios': '20 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2020 - 2022',
#   'sinopsis': '"El Fantasma" sigue a Tariq malabareando sus operaciones de drogas, calificaciones, vida amorosa y familia. Para evitar el destino de su padre, debe convertirse en él, pe'},
#  {'titulo': 'Fleming: El Hombre Que Sería Bond',
#   'clasificacion': 'SAM16',
#   'episodios': '4 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2014',
#   'sinopsis': 'Drama de acción basado en la historia de la vida de Ian Fleming, creador de Jam'},
#  {'titulo': 'Blindspotting',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': '“Blindspotting” es protagonizada por Ashley que vive en Oakland, donde su novio y padre de su hijo es encarcelado; esta situación la deja en la nada y le produce una cris'},
#  {'titulo': 'MalaYerba',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': 'Cuando el cannabis medicinal es legalizado en Colombia, tres jóvenes emprendedores rápidamente se abren paso en el codiciado '},
#  {'titulo': 'Wrong Man',
#   'clasificacion': 'SAM16',
#   'episodios': '13 EPISODIOS',
#   'genero': 'DOCUMENTAL, DRAMA',
#   'año': '2018 - 2020',
#   'sinopsis': 'Un equipo de expertos junto con investigadores locales buscan la verdad que hay detrás de casos criminales de convictos que fueron encarcelados por décadas y que presum'},
#  {'titulo': 'Sweetbitter',
#   'clasificacion': 'SAM16',
#   'episodios': '14 EPISODIOS',
#   'genero': 'DRAMA, LITERARIA',
#   'año': '2018 - 2019',
#   'sinopsis': 'Tess empieza a trabajar en uno de los restaurantes más elegantes de Nueva York, pensando en que sería un trabajo temporal, pero pronto se vio imbuida en al ambiente de s'},
#  {'titulo': 'Chasing Life',
#   'clasificacion': 'SAM13',
#   'episodios': '34 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2014 - 2015',
#   'sinopsis': 'Chasing Life sigue a April, una periodista de veintitantos años cuya vida finalmente se está arreglando. Cuando repentinamente le diagnostican cáncer, su mundo se pone '},
#  {'titulo': 'The Stand',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2020 - 2021',
#   'sinopsis': 'The Stand es la visión apocalíptica de Stephen King de un mundo asolado por una plaga y envuelto en una lucha básica entre el bien y el mal. El destino de la humanid'},
#  {'titulo': 'Power',
#   'clasificacion': 'SAM16',
#   'episodios': '66 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2014 - 2021',
#   'sinopsis': 'El productor ejecutivo Curtis “50 Cent” Jackson presenta "Power," un drama criminal sobre el dueño de un club nocturno quien también es el capo de un lucrativo imperio '},
#  {'titulo': 'Baptiste',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019 - 2021',
#   'sinopsis': 'El impredecible detective, Julien Baptiste, quien está de vacaciones con su esposa en Ámsterdam, apoya a su exnovia, la Jefa de Policía de Ámsterdam, en una invest'},
#  {'titulo': 'The Girlfriend Experience',
#   'clasificacion': 'SAM16',
#   'episodios': '38 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2016 - 2021',
#   'sinopsis': '"The Girlfriend Experience" es la reinvención de la aclamada película en 2009 del mismo nombre de Steven Soderbergh y explora las relaciones entre acompañantes exclusivas'},
#  {'titulo': 'Heels',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': 'Dos hermanos y rivales en el ring - uno el villano o “heel”, el otro el héroe o “face” -se disputan el triunfo en la liga de lucha libre de su padre fallecido, buscan '},
#  {'titulo': 'Instinto Animal',
#   'clasificacion': 'SAM16',
#   'episodios': '49 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2016 - 2019',
#   'sinopsis': 'Este drama sobre una familia criminal sigue a un adolescente quien, luego de la muerte de su madre, se muda con sus parientes independientes a un balneario del sur '},
#  {'titulo': 'Express',
#   'clasificacion': 'SAM16',
#   'episodios': '2 EPISODIOS',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2021 - 2022',
#   'sinopsis': 'Bárbara Vázquez, brillante psicóloga criminal, presenta su renuncia en la Policía y comienza a trabajar en Zentral Risk, una aseguradora cuyo producto estrella es una póli'},
#  {'titulo': 'The White Queen',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DRAMA, LITERARIA',
#   'año': '2013',
#   'sinopsis': '"The White Queen" es una fascinante historia de amor y deseo, traición y asesinatos, en donde se tejen vibrantemente las historias de tres mujeres diferentes pero igualmen'},
#  {'titulo': 'The Dresden Files',
#   'clasificacion': 'SAM13',
#   'episodios': '12 EPISODIOS',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2007',
#   'sinopsis': 'Harry Dresden (Paul Blackthorne), detective privado con habilidades extraordinarias. Ayuda a la policía con delitos al parecer inexplicables y sigue sus propios caso'},
#  {'titulo': 'The Rook',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA, FANTASÍA',
#   'año': '2019',
#   'sinopsis': 'Cuando una mujer despierta rodeada de cadáveres sin ningún recuerdo, debe revelar su misterioso pasado para conocer la'},
#  {'titulo': 'Pennyworth',
#   'clasificacion': 'SAM16',
#   'episodios': '22 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019 - 2021',
#   'sinopsis': 'Esta historia original de DC sigue al legendario mayordomo de Bruce Wayne, Alfred Pennyworth, exsoldado británico del Servicio Aéreo Especial que funda una empresa '},
#  {'titulo': 'The Attaché',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': 'Avshalom, un músico exitoso, se traslada a París cuando su esposa Annabelle consigue un trabajo allí. Son recibidos por ataques terroristas y el sueño de un año romántico '},
#  {'titulo': 'Das Boot',
#   'clasificacion': 'SAM16',
#   'episodios': '16 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2018 - 2020',
#   'sinopsis': 'En 1942, en la Francia ocupada, el U-612 está listo para su primer viaje, dirigiéndose a la guerra que es cada vez más violenta, con su joven tripulación y su nuevo capitá'},
#  {'titulo': 'America To Me',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'DOCUMENTAL',
#   'año': '2018',
#   'sinopsis': 'La serie documental sin libreto “América para mí” lidia con problemas cruciales al plantear preguntas complejas y controvertidas, como se ve a través de los ojos de '},
#  {'titulo': 'The Little Drummer Girl',
#   'clasificacion': 'SAM16',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DRAMA, MINISERIE',
#   'año': '2018',
#   'sinopsis': 'Un asesino palestino está focalizándose en israelíes prominentes. Los israelíes reclutan una actriz inglesa para infiltrarse en su célula terrorista. Esto requerirá todo '},
#  {'titulo': 'The Name of the Rose',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019',
#   'sinopsis': 'En 1327, un brillante monje franciscano ingés, Guillermo de Baskerville, es enviado por el Santo Imperio Romano a un monasterio aislado al norte de Italia para un dramáti'},
#  {'titulo': 'Little Birds',
#   'clasificacion': 'SAM16',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DRAMA, ROMÁNTICA',
#   'año': '2021',
#   'sinopsis': 'Una Adaptación de la infame conlección de cuentos eróticos de An'},
#  {'titulo': 'Dublin Murders',
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2019',
#   'sinopsis': '“Dublin Murders” es una serie de misterio de ocho episodios con una trama que se adentra profundamente en el pasado de Irlanda, presagia su presente y brinda una percepci'},
#  {'titulo': 'Black Sails',
#   'clasificacion': 'SAM16',
#   'episodios': '38 EPISODIOS',
#   'genero': 'DRAMA, ACCIÓN',
#   'año': '2014 - 2017',
#   'sinopsis': 'La aventura pirata "Black Sails", se centra en las historias del capitán Flint y su notoria tripulación mientras luchan por la fortuna y la supervivencia antes de l'},
#  {'titulo': 'Confronting a Serial Killer',
#   'clasificacion': 'SAM16',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DOCUMENTAL, DRAMA',
#   'año': '2021',
#   'sinopsis': 'La asombrosa historia de la relación sin precedentes entre la aclamada autora y periodista Jillian Lauren y el asesino en serie más prolífico de la historia de Estad'},
#  {'titulo': 'High Fidelity',
#   'clasificacion': 'SAM16',
#   'episodios': '11 EPISODIOS',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2020',
#   'sinopsis': 'Una re-imaginación de la novela de 1995 de Nick Hornby, "High Fidelity" se centra en Rob, una dueña de una tienda de discos que recuerda las relaciones pasadas a través '},
#  {'titulo': 'The Act',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DOCUDRAMA, DRAMA',
#   'año': '2019',
#   'sinopsis': 'De los escritores Nick Antosca ("Channel Zero") y Michelle Dean llega "The Act", una serie psicológica y antológica de crímenes reales que cuenta las insólitas histori'},
#  {'titulo': 'The Spanish Princess',
#   'clasificacion': 'SAM16',
#   'episodios': '17 EPISODIOS',
#   'genero': 'DRAMA, HISTÓRICA',
#   'año': '2019 - 2020',
#   'sinopsis': '"The Spanish Princess" es la vívida y cautivante narración de la historia de Catalina de Aragón, que ha sido históricamente eclipsada por su infame matrimonio con el r'},
#  {'titulo': 'Normal People',
#   'clasificacion': 'SAM16',
#   'episodios': '13 EPISODIOS',
#   'genero': 'DRAMA, ROMÁNTICA',
#   'año': '2020',
#   'sinopsis': 'Desde la escuela a la universidad, Normal People sigue a Connell y Marianne mientras entretejen sus vidas en un programa que explora lo complicado que puede ser el am'},
#  {'titulo': 'The Capture',
#   'clasificacion': 'SAM13',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019',
#   'sinopsis': 'Del productor ejecutivo de éxitos David Heyman y NBCUniversal International Studios llega "La captura", un oportuno thriller que explora cuestiones urgentes acerca de '},
#  {'titulo': 'Manhunt: Deadly Games',
#   'clasificacion': 'SAM13',
#   'episodios': '10 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2020',
#   'sinopsis': 'Después de un mortal ataque terrorista en los Juegos Olímpicos de 1996, los agentes del FBI cazan a un escurridizo atacante en serie, mientras que un hombre inocente acusa'},
#  {'titulo': 'P-Valley',
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2020',
#   'sinopsis': 'En la profundidad de Mississippi Delta yace un oasis de diversión y glamour en un momento difícil para la existencia humana donde la belleza es difícil de en'},
#  {'titulo': 'Leavenworth',
#   'clasificacion': 'SAM16',
#   'episodios': '6 EPISODIOS',
#   'genero': 'DOCUMENTAL, DRAMA',
#   'año': '2019 - 2020',
#   'sinopsis': '"Leavenworth" está basada en la polémica historia real de Clint Lorance, un ex teniente, que cumple una condena de 19 años por homicidio en la prisión estadounidense '},
#  {'titulo': 'Run the World',
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': '"Run the World" es una serie de ocho episodios de media hora de duración que cuenta la historia de un grupo de mujeres negras, vibrantes y leales mejores amigas, q'},
#  {'titulo': "No Man's Land",
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'DRAMA, GUERRA',
#   'año': '2020',
#   'sinopsis': 'La hermana de Antoine lleva varios años declarada muerta, pero él está convencido de que está viva. Viaja a Siria, donde las combatientes kurdas luchan cont'},
#  {'titulo': 'Luther',
#   'clasificacion': 'SAM16',
#   'episodios': '20 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2010 - 2019',
#   'sinopsis': 'Un oscuro drama psicológico donde Idris Elba interpreta a Luther, un hombre que lucha contra sus propios demonios terribles, que podría ser tan peligroso como los depravad'},
#  {'titulo': 'Los Miserables',
#   'clasificacion': 'SAM13',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019',
#   'sinopsis': 'En el contexto épico de Francia en una época de disturbios civiles, "Les Misérables" es la historia de Jean Valjean, un ex convicto incapaz de escapar de la sombra de '},
#  {'titulo': 'Castle Rock',
#   'clasificacion': 'SAM16',
#   'episodios': '21 EPISODIOS',
#   'genero': 'DRAMA, FANTASÍA',
#   'año': '2018 - 2020',
#   'sinopsis': '"Castle Rock" lleva a los espectadores al escalofriante mundo del exitoso y aclamado Stephen King en esta serie de terror psic'},
#  {'titulo': 'The Great',
#   'clasificacion': 'SAM16',
#   'episodios': '17 EPISODIOS',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2020 - 2021',
#   'sinopsis': 'The Great es un drama cómico y satírico, ocasionalmente basado en hechos históricos, sobre cómo Catalina la Grande pasó de ser una forastera a la gobernante mujer con '},
#  {'titulo': 'And Then There Were None',
#   'clasificacion': 'SAM13',
#   'episodios': '3 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2015',
#   'sinopsis': 'Basado en la novela policíaca más vendida de todos los tiempos por Agatha Christie. Ocho extraños son atraídos a una isla aislada en la costa de Devon, donde pronto que'},
#  {'titulo': 'Step Up',
#   'clasificacion': 'SAM13',
#   'episodios': '20 EPISODIOS',
#   'genero': 'DRAMA, MÚSICA',
#   'año': '2018 - 2019',
#   'sinopsis': 'Basada en las películas favoritas de los fans, la serie Step Up es un drama emocionante, sexy, y lleno de música sobre bailarines en una escuela de artes escénic'},
#  {'titulo': 'Houdini',
#   'clasificacion': 'SAM13',
#   'episodios': '2 EPISODIOS',
#   'genero': 'DRAMA, HISTÓRICA',
#   'año': '2014',
#   'sinopsis': 'Adrien Brody, ganador del Premio de la Academia*, y Kristen Connolly estelarizan HOUDINI, que sigue la transformación de inmigrante a superestrella del mundialmente famo'},
#  {'titulo': 'Power Book IV: Force',
#   'clasificacion': 'SAM16',
#   'episodios': '1 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2021',
#   'sinopsis': 'Tommy Egan corta todos los lazos y pone a Nueva York en su espejo retrovisor para siempre cuando llega a Chicago, proponiendo convertirse en el mayor traficante de drog'},
#  {'titulo': 'MotherFatherSon',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2019',
#   'sinopsis': 'Max posee uno de los imperios mediáticos más influyentes del mundo. La información es su oficio: tiene secretos oscuros para todos y usa su poder despiadadamente, incluso '},
#  {'titulo': 'The Kill Point',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2007',
#   'sinopsis': '"Este drama lleno de testosterona trata de un grupo de veteranos de guerra insensibilizados, quienes se enfrentan a un negociador de rehenes que se niega a retroced'},
#  {'titulo': 'Gangs of London',
#   'clasificacion': 'SAM16',
#   'episodios': '10 EPISODIOS',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2020',
#   'sinopsis': 'Tras el asesinato del líder de una banda criminal, el vacío de poder amenaza la frágil paz entre la compleja red de pandillas que operan en las calles de '},
#  {'titulo': 'The Night Manager',
#   'clasificacion': 'SAM13',
#   'episodios': '6 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2016',
#   'sinopsis': '"The Night Manager" es un apasionante thriller de espionaje, muestra las andanzas del ex soldado inglés Jonathan Pine (Hiddleston), que, tras incorporarse al servicio '},
#  {'titulo': 'Spartacus',
#   'clasificacion': 'SAM16',
#   'episodios': '39 EPISODIOS',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2010 - 2013',
#   'sinopsis': 'Traicionado por Romanos. Forzado a la esclavitud. Renacido como Gladiador. Apartado de su patria y su mujer, Spartacus es condenado al mundo de la arena donde la sangre y '},
#  {'titulo': 'Flesh And Bone',
#   'clasificacion': 'SAM16',
#   'episodios': '8 EPISODIOS',
#   'genero': 'DANZA, DRAMA',
#   'año': '2015',
#   'sinopsis': 'Esta oscura y delicada serie sigue a una joven bailarina, Claire, que se une a una prestigiosa compañía de ballet de la ciudad de Nueva York y se encuentra con el glamour'},
#  {'titulo': 'Boss',
#   'clasificacion': 'SAM16',
#   'episodios': '18 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2011 - 2012',
#   'sinopsis': 'El alcalde Tom Kane (Kelsey Grammer) es el rey de Chicago y gobierna su dominio con un puño de hierro. El engaño, el escándalo y la traición van de la mano con la forma '},
#  {'titulo': 'Penny Dreadful',
#   'clasificacion': 'SAM16',
#   'episodios': '27 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2014 - 2016',
#   'sinopsis': 'Penny Dreadful es un thriller psicológico lleno de un oscuro misterio y de suspenso, donde los demonios personales del pasado pueden ser más fuertes que los vampiros, l'},
#  {'titulo': 'Dr. Death',
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2021',
#   'sinopsis': 'Basada en el exitoso podcast de Wondery, Dr. Death cuanta la impactante historia verdadera del Dr. Christopher Duntsch (Joshua Jackson), un joven neurocirujano aparentemen'},
#  {'titulo': 'BMF',
#   'clasificacion': 'SAM16',
#   'episodios': '9 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2021',
#   'sinopsis': '"BMF" sigue la historia de dos hermanos que crearon la "Black Mafia Family", la red de distribución de drogas más promienente en la historia Am'},
#  {'titulo': "Rosemary's Baby",
#   'clasificacion': 'SAM13',
#   'episodios': '2 EPISODIOS',
#   'genero': 'SUSPENSO',
#   'año': '2014',
#   'sinopsis': '"Rosemary\'s Baby" es la nueva versión de la novela de superventas de Ira levin, que sigue a una mujer embarazada quien descubre una trama siniestra alrededor de su bebé '},
#  {'titulo': 'The Borgias',
#   'clasificacion': 'SAM16',
#   'episodios': '29 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2011 - 2013',
#   'sinopsis': 'Sexo. Poder. Asesinato. Amén. Jeremy Irons, ganador del Oscar®, protagoniza esta nueva y épica serie original de Showtime, The Borgias, la historia explosiva de la prime'},
#  {'titulo': 'Reign',
#   'clasificacion': 'SAM13',
#   'episodios': '78 EPISODIOS',
#   'genero': 'DRAMA',
#   'año': '2013 - 2017',
#   'sinopsis': 'La historia comienza en el año 1557 cuando Mary, Reina de Escocia, tiene que partir del convento en el que vivía hacia Francia, para contraer matrimonio con el Prínci'},
#  {'titulo': 'Wolf Creek',
#   'clasificacion': 'SAM16',
#   'episodios': '12 EPISODIOS',
#   'genero': 'DRAMA, DE TERROR',
#   'año': '2016 - 2017',
#   'sinopsis': 'Mick Taylor regresa para causar estragos en Wolf Creek. Excepto que esta vez una víctima se defiende. La única sobreviviente de la masacre de su familia, la estudian'},
#  {'titulo': 'Dr. Death: The Undoctored Story',
#   'clasificacion': 'SAM13',
#   'episodios': '4 EPISODIOS',
#   'genero': 'DOCUMENTAL, DRAMA',
#   'año': '2021',
#   'sinopsis': '"Dr. Death: The Undoctored Story" es la primera docuserie sobre el Dr. Christopher Duntsch, el notorio neurocirujano, cuya historia impactante ha cautivado a'}]

# %%
#Transform list to pandas dataframe.
df = pd.DataFrame(lista_series)

# %%
df
# Out:
#                              titulo clasificacion     episodios  \
# 0                       Howards End         SAM13   4 EPISODIOS
# 1                              Vida         SAM16  23 EPISODIOS
# 2          Warriors Of Liberty City         SAM16   6 EPISODIOS
# 3               Blue Mountain State         SAM16  39 EPISODIOS
# 4                      Sr. Mercedes         SAM16  30 EPISODIOS
# ..                              ...           ...           ...
# 66                  Rosemary's Baby         SAM13   2 EPISODIOS
# 67                      The Borgias         SAM16  29 EPISODIOS
# 68                            Reign         SAM13  78 EPISODIOS
# 69                       Wolf Creek         SAM16  12 EPISODIOS
# 70  Dr. Death: The Undoctored Story         SAM13   4 EPISODIOS
#
#                   genero          año  \
# 0       DRAMA, LITERARIA         2018
# 1         COMEDIA, DRAMA  2018 - 2020
# 2   DOCUMENTAL, DEPORTES         2018
# 3      COMEDIA, DEPORTES  2010 - 2011
# 4       CRIMEN, SUSPENSO  2017 - 2019
# ..                   ...          ...
# 66              SUSPENSO         2014
# 67                 DRAMA  2011 - 2013
# 68                 DRAMA  2013 - 2017
# 69      DRAMA, DE TERROR  2016 - 2017
# 70     DOCUMENTAL, DRAMA         2021
#
#                                              sinopsis
# 0   "Howards End" es la historia de dos hermanas i...
# 1   "Vida" es una serie de media hora que se enfoc...
# 2   La serie sigue a los Guerreros de Liberty City...
# 3   En Blue Mountain State, el campus universitari...
# 4   Un asesino serial demente se burla de un polic...
# ..                                                ...
# 66  "Rosemary's Baby" es la nueva versión de la no...
# 67  Sexo. Poder. Asesinato. Amén. Jeremy Irons, ga...
# 68  La historia comienza en el año 1557 cuando Mar...
# 69  Mick Taylor regresa para causar estragos en Wo...
# 70  "Dr. Death: The Undoctored Story" es la primer...
#
# [71 rows x 6 columns]

# %%
#Save it to csv file
df.to_csv('datasets/series.csv')

# %%
#Save it to json file
df.to_json('datasets/series.json')

# %%
driver.quit()
