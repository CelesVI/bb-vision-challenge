# %%
#Import all necesaries libraries
from selenium import webdriver
import pandas as pd
import time

# %%
#Get url to scrap all the movies.
url_pelis = "https://www.starz.com/ar/es/view-all/blocks/1523534"

# %%
#Create an instance of webdriver to scrap.
#It uses an chrome driver located on root path.
driver = webdriver.Chrome(executable_path = r'chromedriver.exe')

# %%
#Set url to the drive. Wait 8 seconds to load all the data from url.
driver.get(url_pelis)
time.sleep(8)

# %%
#The movies links are located on view-all-scrollable class.
#Get the view-all-scrollable object.
html = driver.find_element_by_class_name('view-all-scrollable')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-21-2ab161fff3a1> in <module>
#       1 #The movies links are located on view-all-scrollable class.
#       2 #Get the view-all-scrollable object.
# ----> 3 html = driver.find_element_by_class_name('view-all-scrollable')
#
# c:\users\bravin\appdata\local\programs\python\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# c:\users\bravin\appdata\local\programs\python\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# c:\users\bravin\appdata\local\programs\python\python38\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# c:\users\bravin\appdata\local\programs\python\python38\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=97.0.4692.99)

# %%
html
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="128e89ca245f1cc72465a3de58bec5f0", element="2195c03f-9a67-4b70-86b8-b27210492e6b")>

# %%
#Create an empty list to get all links in html variable.
lista_links = []

# %%
#Iterate throught xpath looking for href attribute.
for link in driver.find_elements_by_xpath('.//a'):
    lista_links.append(link.get_attribute('href'))

# %%
#Filter none objects.
lista_links = list(filter(None, lista_links))

# %%
lista_links
# Out:
# ['https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/signup',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies/m%C3%A1s-fuerte-que-el-destino-62674',
#  'https://www.starz.com/ar/es/movies/m%C3%A1s-fuerte-que-el-destino-62674',
#  'https://www.starz.com/ar/es/movies/dulce-venganza-2-25826',
#  'https://www.starz.com/ar/es/movies/dulce-venganza-2-25826',
#  'https://www.starz.com/ar/es/movies/al-borde-del-abismo-49297',
#  'https://www.starz.com/ar/es/movies/al-borde-del-abismo-49297',
#  'https://www.starz.com/ar/es/movies/si-no-despierto-51601',
#  'https://www.starz.com/ar/es/movies/si-no-despierto-51601',
#  'https://www.starz.com/ar/es/movies/maria-antonieta-la-reina-adolescente-14139',
#  'https://www.starz.com/ar/es/movies/maria-antonieta-la-reina-adolescente-14139',
#  'https://www.starz.com/ar/es/movies/r%C3%A1pido-y-fogoso-44850',
#  'https://www.starz.com/ar/es/movies/r%C3%A1pido-y-fogoso-44850',
#  'https://www.starz.com/ar/es/movies/crep%C3%BAsculo-la-saga-amanecer-%E2%80%93-parte-2-50834',
#  'https://www.starz.com/ar/es/movies/crep%C3%BAsculo-la-saga-amanecer-%E2%80%93-parte-2-50834',
#  'https://www.starz.com/ar/es/movies/john-wick-2-un-nuevo-d%C3%ADa-para-matar-61327',
#  'https://www.starz.com/ar/es/movies/john-wick-2-un-nuevo-d%C3%ADa-para-matar-61327',
#  'https://www.starz.com/ar/es/movies/jigsaw-el-juego-contin%C3%BAa-62688',
#  'https://www.starz.com/ar/es/movies/jigsaw-el-juego-contin%C3%BAa-62688',
#  'https://www.starz.com/ar/es/movies/dulce-venganza-9303',
#  'https://www.starz.com/ar/es/movies/dulce-venganza-9303',
#  'https://www.starz.com/ar/es/movies/la-enfermera-28990',
#  'https://www.starz.com/ar/es/movies/la-enfermera-28990',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo
#  'https://www.starz.com/ar/es/movies/mamma-mia-50021',
#  'https://www.starz.com/ar/es/movies/la-novia-de-mi-mejor-amigo-50076',
#  'https://www.starz.com/ar/es/movies/la-novia-de-mi-mejor-amigo-50076',
#  'https://www.starz.com/ar/es/movies/red-retirados-extremadamente-duros-50355',
#  'https://www.starz.com/ar/es/movies/red-retirados-extremadamente-duros-50355',
#  'https://www.starz.com/ar/es/movies/el-lado-oscuro-del-deseo-50862',
#  'https://www.starz.com/ar/es/movies/el-lado-oscuro-del-deseo-50862',
#  'https://www.starz.com/ar/es/movies/esc%C3%A1ndalo-americano-50880',
#  'https://www.starz.com/ar/es/movies/esc%C3%A1ndalo-americano-50880',
#  'https://www.starz.com/ar/es/movies/decisi%C3%B3n-final-51070',
#  'https://www.starz.com/ar/es/movies/decisi%C3%B3n-final-51070',
#  'https://www.starz.com/ar/es/movies/escondida-51619',
#  'https://www.starz.com/ar/es/movies/escondida-51619',
#  'https://www.starz.com/ar/es/movies/repugnante-52012',
#  'https://www.starz.com/ar/es/movies/repugnante-52012',
#  'https://www.starz.com/ar/es/movies/pasi%C3%B3n-inocente-52225',
#  'https://www.starz.com/ar/es/movies/pasi%C3%B3n-inocente-52225',
#  'https://www.starz.com/ar/es/movies/cr%C3%ADmenes-ocultos-59236',
#  'https://www.starz.com/ar/es/movies/cr%C3%ADmenes-ocultos-59236',
#  'https://www.starz.com/ar/es/movies/campamento-del-terror-60727',
#  'https://www.starz.com/ar/es/movies/campamento-del-terror-60727',
#  'https://www.starz.com/ar/es/movies/hellraiser-juicio-62668',
#  'https://www.starz.com/ar/es/movies/hellraiser-juicio-62668',
#  'https://www.starz.com/ar/es/movies/competencia-en-la-cocina-62670',
#  'https://www.starz.com/ar/es/movies/competencia-en-la-cocina-62670',
#  'https://www.starz.com/ar/es/movies/d%C3%ADa-del-atentado-62672',
#  'https://www.starz.com/ar/es/movies/d%C3%ADa-del-atentado-62672',
#  'https://www.starz.com/ar/es/movies/una-navidad-a-la-moda-real-62682',
#  'https://www.starz.com/ar/es/movies/una-navidad-a-la-moda-real-62682',
#  'https://www.starz.com/ar/es/movies/la-maldici%C3%B3n-de-la-casa-winchester-62694',
#  'https://www.starz.com/ar/es/movies/la-maldici%C3%B3n-de-la-casa-winchester-62694',
#  'https://www.starz.com/ar/es/movies/father-figures-62698',
#  'https://www.starz.com/ar/es/movies/father-figures-62698',
#  'https://www.starz.com/ar/es/movies/el-legado-62756',
#  'https://www.starz.com/ar/es/movies/el-legado-62756',
#  'https://www.starz.com/ar/es/movies/querido-santa-secreto-63449',
#  'https://www.starz.com/ar/es/movies/querido-santa-secreto-63449',
#  'https://www.starz.com/ar/es/movies/una-navidad-a-la-medida-63545',
#  'https://www.starz.com/ar/es/movies/una-navidad-a-la-medida-63545',
#  'https://www.starz.com/ar/es/movies/la-cumbre-escarlata-65822',
#  'https://www.starz.com/ar/es/movies/la-cumbre-escarlata-65822',
#  'https://www.starz.com/ar/es/movies/el-duende-2-25250',
#  'https://www.starz.com/ar/es/movies/el-duende-2-25250',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/browse/originals',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/series',
#  'https://www.starz.com/ar/es/signup',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/faq',
#  'https://www.starz.com/ar/es/login/activate',
#  'https://www.starz.com/ar/es/supporteddevices',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.facebook.com/STARZPLAYLATAM/',
#  'https://twitter.com/starzplaylatam',
#  'https://www.instagram.com/starzplaylatam/',
#  'https://www.starz.com/ar/es/',
#  'https://www.starz.com/ar/es/login',
#  'https://www.starz.com/ar/es/search',
#  'https://www.starz.com/ar/es/series/express/63120',
#  'https://www.starz.com/ar/es/series/power-book-iv-force/62261',
#  'https://www.starz.com/ar/es/series/baptiste/45713',
#  'https://www.starz.com/ar/es/series/the-great/57979',
#  'https://www.starz.com/ar/es/series/power-book-ii-ghost/58002',
#  'https://www.starz.com/ar/es/series/malayerba/64882',
#  'https://www.starz.com/ar/es/series/dr-death-the-undoctored-story/65195',
#  'https://www.starz.com/ar/es/series/hightown/57463',
#  'https://www.starz.com/ar/es/series/bmf/62264',
#  'https://www.starz.com/ar/es/series/dr-death/61268',
#  'https://www.starz.com/ar/es/series/heels/60760',
#  'https://www.starz.com/ar/es/series/the-girlfriend-experience/25586',
#  'https://www.starz.com/ar/es/series/power-book-iii-raising-kanan/58458',
#  'https://www.starz.com/ar/es/series/blindspotting/62263',
#  'https://www.starz.com/ar/es/series/run-the-world/58457',
#  'https://www.starz.com/ar/es/series/confronting-a-serial-killer/59920',
#  'https://www.starz.com/ar/es/series/pennyworth/57149',
#  'https://www.starz.com/ar/es/series/the-act/46154',
#  'https://www.starz.com/ar/es/series/the-attach%C3%A9/62262',
#  'https://www.starz.com/ar/es/series/the-stand/61994',
#  'https://www.starz.com/ar/es/series/little-birds/62168',
#  'https://www.starz.com/ar/es/series/normal-people/60083',
#  'https://www.starz.com/ar/es/series/p-valley/46156',
#  'https://www.starz.com/ar/es/series/seduced-inside-the-nxivm-cult/59967',
#  'https://www.starz.com/ar/es/series/the-night-manager/61267',
#  'https://www.starz.com/ar/es/series/gangs-of-london/60530',
#  'https://www.starz.com/ar/es/series/no-mans-land/61940',
#  'https://www.starz.com/ar/es/series/castle-rock/45522',
#  'https://www.starz.com/ar/es/series/flesh-and-bone/24528',
#  'https://www.starz.com/ar/es/series/the-spanish-princess/42457',
#  'https://www.starz.com/ar/es/browse/genre/acci%C3%B3n',
#  'https://www.starz.com/ar/es/browse/genre/comedias',
#  'https://www.starz.com/ar/es/browse/genre/cr%C3%ADmenes-reales',
#  'https://www.starz.com/ar/es/browse/genre/de-terror',
#  'https://www.starz.com/ar/es/browse/genre/dramas',
#  'https://www.starz.com/ar/es/browse/genre/dramas-de-%C3%A9poca',
#  'https://www.starz.com/ar/es/browse/genre/nuevos-lanzamientos',
#  'https://www.starz.com/ar/es/browse/genre/rom%C3%A1nticas',
#  'https://www.starz.com/ar/es/browse/genre/series-dram%C3%A1ticas-de-relaciones',
#  'https://www.starz.com/ar/es/browse/genre/series-policiales',
#  'https://www.starz.com/ar/es/browse/genre/si-te-gusta-the-great',
#  'https://www.starz.com/ar/es/browse/genre/thriller',
#  'https://www.starz.com/ar/es/browse/genre/%C3%BAltima-oportunidad']

# %%
#Movies links have '/movies/' string on their urls.
#Create a varible to filter later.
movies_match = '/movies/'

# %%
#List comprehension to filter by the previous string.
#Convert to set to remove duplicates.
#Then, convert to list again to iterate.
#Now, we have the links of all movies.
useful_links = list(set([link for link in lista_links if movies_match in link]))

# %%
useful_links
# Out:
# ['https://www.starz.com/ar/es/movies/una-navidad-a-la-moda-real-62682',
#  'https://www.starz.com/ar/es/movies/a-conseguir-trabajo-30233',
#  'https://www.starz.com/ar/es/movies/la-novia-de-mi-mejor-amigo-50076',
#  'https://www.starz.com/ar/es/movies/decisi%C3%B3n-final-51070',
#  'https://www.starz.com/ar/es/movies/2012-37333',
#  'https://www.starz.com/ar/es/movies/bu-2-una-noche-de-brujas-de-madea-de-tyler-perry-51713',
#  'https://www.starz.com/ar/es/movies/red-2-50631',
#  'https://www.starz.com/ar/es/movies/crep%C3%BAsculo-la-saga-amanecer-%E2%80%93-parte-2-50834',
#  'https://www.starz.com/ar/es/movies/el-sorprendente-hombre-ara%C3%B1a-2-la-amenaza-de-electro-50064',
#  'https://www.starz.com/ar/es/movies/cartas-a-julieta-50199',
#  'https://www.starz.com/ar/es/movies/horizonte-profundo-62067',
#  'https://www.starz.com/ar/es/movies/tropa-de-%C3%A9lite-51922',
#  'https://www.starz.com/ar/es/movies/12-horas-51692',
#  'https://www.starz.com/ar/es/movies/una-boda-para-navidad-62684',
#  'https://www.starz.com/ar/es/movies/de-tyler-perry-por-qu%C3%A9-me-cas%C3%A9-tambi%C3%A9n-50512',
#  'https://www.starz.com/ar/es/movies/golpe-en-londres-62696',
#  'https://www.starz.com/ar/es/movies/la-redada-34897',
#  'https://www.starz.com/ar/es/movies/m%C3%A1s-fuerte-que-el-destino-62674',
#  'https://www.starz.com/ar/es/movies/dulce-venganza-2-25826',
#  'https://www.starz.com/ar/es/movies/anna-karenina-41102',
#  'https://www.starz.com/ar/es/movies/una-navidad-a-la-medida-63545',
#  'https://www.starz.com/ar/es/movies/repugnante-52012',
#  'https://www.starz.com/ar/es/movies/un-paso-adelante-24244',
#  'https://www.starz.com/ar/es/movies/dura-verdad-50508',
#  'https://www.starz.com/ar/es/movies/d%C3%ADa-del-atentado-62672',
#  'https://www.starz.com/ar/es/movies/john-wick-2-un-nuevo-d%C3%ADa-para-matar-61327',
#  'https://www.starz.com/ar/es/movies/la-reina-25264',
#  'https://www.starz.com/ar/es/movies/pobres-divas-50421',
#  'https://www.starz.com/ar/es/movies/si-no-despierto-51601',
#  'https://www.starz.com/ar/es/movies/la-maldici%C3%B3n-de-blackwood-62692',
#  'https://www.starz.com/ar/es/movies/el-grito-29285',
#  'https://www.starz.com/ar/es/movies/son-como-ni%C3%B1os-2-50698',
#  'https://www.starz.com/ar/es/movies/lo-que-pas%C3%B3-reci%C3%A9n-60739',
#  'https://www.starz.com/ar/es/movies/competencia-en-la-cocina-62670',
#  'https://www.starz.com/ar/es/movies/el-karate-kid-6462',
#  'https://www.starz.com/ar/es/movies/empire-state-el-gran-robo-del-bronx-30698',
#  'https://www.starz.com/ar/es/movies/ali-37309',
#  'https://www.starz.com/ar/es/movies/cubos-47298',
#  'https://www.starz.com/ar/es/movies/r%C3%A1pido-y-fogoso-44850',
#  'https://www.starz.com/ar/es/movies/crank-muerte-anunciada-49809',
#  'https://www.starz.com/ar/es/movies/al-borde-del-abismo-49297',
#  'https://www.starz.com/ar/es/movies/triple-x-49275',
#  'https://www.starz.com/ar/es/movies/la-maldici%C3%B3n-de

#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-en-llamas-50815',
#  'https://www.starz.com/ar/es/movies/los-juegos-del-hambre-sinsajo-el-final-50756',
#  'https://www.starz.com/ar/es/movies/de-tyler-perry-las-ni%C3%B1as-de-pap%C3%A1-39528',
#  'https://www.starz.com/ar/es/movies/la-caba%C3%B1a-57174',
#  'https://www.starz.com/ar/es/movies/el-justiciero-22163',
#  'https://www.starz.com/ar/es/movies/47-ronin-52304',
#  'https://www.starz.com/ar/es/movies/el-legado-62756',
#  'https://www.starz.com/ar/es/movies/rendirse-jam%C3%A1s-30857',
#  'https://www.starz.com/ar/es/movies/esc%C3%A1ndalo-americano-50880',
#  'https://www.starz.com/ar/es/movies/lugares-oscuros-52235',
#  'https://www.starz.com/ar/es/movies/el-duende-2-25250',
#  'https://www.starz.com/ar/es/movies/plan-de-escape-50202',
#  'https://www.starz.com/ar/es/movies/grey-lady-51947',
#  'https://www.starz.com/ar/es/movies/traficantes-por-error-39896',
#  'https://www.starz.com/ar/es/movies/la-cumbre-escarlata-65822',
#  'https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743',
#  'https://www.starz.com/ar/es/movies/querido-santa-secreto-63449',
#  'https://www.starz.com/ar/es/movies/crep%C3%BAsculo-49947']

# %%
#Empty list to save the collection of dictionaries.
#Dictionary to save metada from movies and append it on the list.
lista_peliculas = []

# %%
#Iterate throught movies link.
#Get data from url and wait 5 second to get all data from the url.
#Get data from xpath and save it.
#Then, create a dictionary to store metadata and append it on the list.
for i in useful_links:
    print(i)
    driver.get(i)
    time.sleep(5)
    titulo = driver.find_element_by_xpath('.//*[@id="moviesDetailsH1"]').text[4:]
    clasificacion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[1]').text
    duracion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[2]').text
    genero = driver.find_element_by_xpath('//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[3]').text
    anio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[4]').text
    tipo_de_audio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[5]').text
    sinopsis = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/div[1]/p[1]').text
    diccionario_pelicula = {
        'titulo':titulo,
        'clasificacion':clasificacion,
        'duracion':duracion,
        'genero':genero,
        'año':anio,
        'tipo_de_audio':tipo_de_audio,
        'sinopsis':sinopsis
    }
    lista_peliculas.append(diccionario_pelicula)
print('******FIN******')
'''
driver.get(useful_links[-1])
time.sleep(3)
titulo = driver.find_element_by_xpath('.//*[@id="moviesDetailsH1"]').text[4:]
clasificacion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[1]').text
duracion = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[2]').text
genero = driver.find_element_by_xpath('//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[3]').text
anio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[4]').text
tipo_de_audio = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[5]').text
sinopsis = driver.find_element_by_xpath('.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/div[1]/p[1]').text
diccionario_pelicula = {
    'titulo':titulo,
    'clasificacion':clasificacion,
    'duracion':duracion,
    'genero':genero,
    'año':anio,
    'tipo_de_audio':tipo_de_audio,
    'sinopsis':sinopsis
}
lista_peliculas.append(diccionario_pelicula)
print('******FIN******')
'''
# Out:
# https://www.starz.com/ar/es/movies/una-navidad-a-la-moda-real-62682
# https://www.starz.com/ar/es/movies/a-conseguir-trabajo-30233
# https://www.starz.com/ar/es/movies/la-novia-de-mi-mejor-amigo-50076
# https://www.starz.com/ar/es/movies/decisi%C3%B3n-final-51070
# https://www.starz.com/ar/es/movies/2012-37333
# https://www.starz.com/ar/es/movies/bu-2-una-noche-de-brujas-de-madea-de-tyler-perry-51713
# https://www.starz.com/ar/es/movies/red-2-50631
# https://www.starz.com/ar/es/movies/crep%C3%BAsculo-la-saga-amanecer
# https://www.starz.com/ar/es/movies/el-legado-62756
# https://www.starz.com/ar/es/movies/rendirse-jam%C3%A1s-30857
# https://www.starz.com/ar/es/movies/esc%C3%A1ndalo-americano-50880
# https://www.starz.com/ar/es/movies/lugares-oscuros-52235
# https://www.starz.com/ar/es/movies/el-duende-2-25250
# https://www.starz.com/ar/es/movies/plan-de-escape-50202
# https://www.starz.com/ar/es/movies/grey-lady-51947
# https://www.starz.com/ar/es/movies/traficantes-por-error-39896
# https://www.starz.com/ar/es/movies/la-cumbre-escarlata-65822
# https://www.starz.com/ar/es/movies/oscura-seducci%C3%B3n-60743
# https://www.starz.com/ar/es/movies/querido-santa-secreto-63449
# https://www.starz.com/ar/es/movies/crep%C3%BAsculo-49947
# ******FIN******
# '\ndriver.get(useful_links[-1])\ntime.sleep(3)\ntitulo = driver.find_element_by_xpath(\'.//*[@id="moviesDetailsH1"]\').text[4:]\nclasificacion = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[1]\').text\nduracion = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[2]\').text\ngenero = driver.find_element_by_xpath(\'//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[3]\').text\nanio = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[4]\').text\ntipo_de_audio = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/section/ul/li[5]\').text\nsinopsis = driver.find_element_by_xpath(\'.//*[@id="subview-container"]/starz-movie-details/div/div/section/div[1]/div[2]/div[1]/p[1]\').text\ndiccionario_pelicula = {\n    \'titulo\':titulo,\n    \'clasificacion\':clasificacion,\n    \'duracion\':duracion,\n    \'genero\':genero,\n    \'año\':anio,\n    \'tipo_de_audio\':tipo_de_audio,\n    \'sinopsis\':sinopsis\n}\nlista_peliculas.append(diccionario_pelicula)\nprint(\'******FIN******\')\n'

# %%
#Show all the movies with their metadata.
lista_peliculas
# Out:
# [{'titulo': 'Una Navidad a la moda real online',
#   'clasificacion': 'ATP',
#   'duracion': '86 MIN',
#   'genero': 'NAVIDEÑA, COMEDIA',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Kristin Cooper, la guapa y talentosa asistente de una firma global de relaciones públicas, es puesta a cargo del Desfile de Moda y Subasta Navideña anual para el empresario de ropa, Sr. Carson.'},
#  {'titulo': 'A conseguir trabajo online',
#   'clasificacion': 'SAM13',
#   'duracion': '82 MIN',
#   'genero': 'COMEDIA, COMEDIA ROMÁNTICA',
#   'año': '2016',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuando Will se queda sin trabajo y a Jillian la despiden, la joven pareja y sus amigos deben soportar la humillación pública, novatadas y pruebas de dopaje sorpresa para poder iniciar sus carreras'},
#  {'titulo': 'La novia de mi mejor amigo online',
#   'clasificacion': 'SAM16',
#   'duracion': '100 MIN',
#   'genero': 'COMEDIA, ROMÁNTICA',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Tank (Dane Cook) se enfrenta a la mayor prueba de amistad posible cuando su mejor amigo (Jason Biggs) lo contrata para que llevé a su ex novia (Kate Hudson) a una pésima cita con el fin de que note lo'},
#  {'titulo': 'Decisión final online',
#   'clasificacion': 'SAM13',
#   'duracion': '109 MIN',
#   'genero': 'DRAMA, DEPORTES',
#   'año': '2014',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'En el día del Draft de la NFL, el gerente general de los Cafés de Cleveland debe decidir que es lo que está dispuesto a sacrificar mientras busca al seleccionado número uno.'},
#  {'titulo': '2012 online',
#   'clasificacion': 'SAM13',
#   'duracion': '157 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2009',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El mundo se enfrenta a una catástrofe de proporciones apocalípticas, las ciudades quedan destruidas y los continentes se desmoronan. En el año 2012 llega el fin del mundo y la heroica lucha de los'},
#  {'titulo': '¡Bu! 2 Una noche de brujas de Madea, de Tyler Perry online',
#   'clasificacion': 'SAM13',
#   'duracion': '100 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuando la hija de Brian, (Tyler Perry) se escapa a una fiesta, en un campamento embrujado, Madea, Bam Hattie y Joe comienzan toda una travesía llena de miedo y diversión para traerla de regreso a'},
#  {'titulo': 'Red 2 online',
#   'clasificacion': 'SAM13',
#   'duracion': '115 MIN',
#   'genero': 'ACCIÓN, COMEDIA',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El ex agente de la CIA Frank Moses y su equipo de desafortunados héroes regresan para otra misión arriesgada, esta vez con la tarea de encontrar un arma nuclear peligrosa.'},
#  {'titulo': 'Crepúsculo la saga: Amanecer – Parte 2 online',
#   'clasificacion': 'SAM13',
#   'duracion': '115 MIN',
#   'genero': 'DE AVENTURAS, DRAMA',
#   'año': '2012',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'En el quinto y último capítulo de la saga de Crepúsculo, el nacimiento del hijo de Bella y Edward enciende las fuerzas que amenazan con destruirlos a todos. Ahora, los Cullen deben conseguir la ayuda'},
#  {'titulo': 'El sorprendente Hombre-Araña 2 - La amenaza de Electro online',
#   'clasificacion': 'SAM13',
#   'duracion': '141 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Ser el Hombre Araña (Andrew Garfield) es genial. Para Peter Parker, no hay mejor sensación que columpiarse entre rascacielos, ser el héroe y pasar el tiempo con Gwen (Emma Stone).'},
#  {'titulo': 'Cartas a Julieta online',
#   'clasificacion': 'ATP',
#   'duracion': '105 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2010',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Mientras está de vacaciones en Verona, Sophie se encuentra con una "carta a Julieta" y se embarca en una misión para encontrar a su autor.'},
#  {'titulo': 'Horizonte profundo online',
#   'clasificacion': 'SAM13',
#   'duracion': '107 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2016',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Horizonte profundo es una historia llena de heroísmo y acción, basada en los hechos reales que sucedieron en la plataforma de Deepwater Horizon en el Golfo de México en 2010. La historia narra la'},
#  {'titulo': 'Tropa de élite online',
#   'clasificacion': 'SAM16',
#   'duracion': '115 MIN',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2007',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Antes de la llegada del Papa a Rio de Janeiro, el Capitán Nascimento de la fuerza BOPE quiere salir de la corporación para dedicarse a enseñar en la academia y poder atender a su esposa embarazada,'},
#  {'titulo': '12 Horas online',
#   'clasificacion': 'SAM13',
#   'duracion': '94 MIN',
#   'genero': 'DRAMA, THRILLER PSICOLÓGICO',
#   'año': '2012',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Hace un año, Jill Parrish sobrevivió al secuestro de un asesino en serie. Cuando llega a casa luego de un turno nocturno descubre que su hermana Molly ha sido secuestrada, y está convencida de que el'},
#  {'titulo': 'UNA BODA PARA NAVIDAD online',
#   'clasificacion': 'ATP',
#   'duracion': '88 MIN',
#   'genero': 'NAVIDEÑA, COMEDIA ROMÁNTICA',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Haley Foster escapó de su infancia en un pequeño pueblo en Pineridge y construyó una gran vida en la ciudad de Los Ángeles como una de las mejores planificadoras de bodas en una poderosa compañía de'},
#  {'titulo': 'De Tyler Perry: ¿Por qué me casé también? online',
#   'clasificacion': 'SAM13',
#   'duracion': '120 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2010',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Con el mismo elenco carismático de la exitosa comedia dramática, "¿Por qué me casé?", Tyler Perry nos trae el siguiente capítulo en la vida de ocho amigos de la universidad que luchan con los desafíos'},
#  {'titulo': 'Golpe en londres online',
#   'clasificacion': 'SAM16',
#   'duracion': '95 MIN',
#   'genero': 'ACCIÓN',
#   'año': '2017',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un atraco a un banco sale mal y alguien es asesinado, pero las cosas pueden no ser lo que parecen.'},
#  {'titulo': 'La redada online',
#   'clasificacion': 'SAM16',
#   'duracion': '101 MIN',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2012',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'En el corazón de la poblada ciudad de Jakarta está el escondite de una pandilla de traficantes. Antes de amanecer un escuadrón de S.W.A.T llega para atrapar al líder, pero cuando la noticia de la'},
#  {'titulo': 'Más fuerte que el destino online',
#   'clasificacion': 'SAM16',
#   'duracion': '118 MIN',
#   'genero': 'DRAMA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Más Fuerte que el Destino está inspirada en la historia de Jeff Bauman, un hombre ordinario quien capturó los corazones del mundo, para convertirse en un símbolo de esperanza, después de la infame'},
#  {'titulo': 'Dulce venganza 2 online',
#   'clasificacion': 'SAM16',
#   'duracion': '106 MIN',
#   'genero': 'DE TERROR',
#   'año': '2013',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Del director de la aclamada remake del 2010, este nuevo episodio impactante muestra a una modelo brutalizada que sobrevive para buscar su venganza. Protagonizada por Jemma Dallender y Joe Absolom.'},
#  {'titulo': 'Anna Karenina online',
#   'clasificacion': 'SAM16',
#   'duracion': '129 MIN',
#   'genero': 'DRAMA, ROMÁNTICA',
#   'año': '2012',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'La historia explora con fuerza la capacidad de amar del corazón humano. Anna (Knightley) duda de su felicidad y de su matrimonio, y los cambios se suceden a su alrededor.'},
#  {'titulo': 'Una Navidad a la medida online',
#   'clasificacion': 'ATP',
#   'duracion': '84 MIN',
#   'genero': 'NAVIDEÑA, FAMILIAR',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Este año Steven acogerá a su familia durante la Navidad, por lo que contrata a una organizadora de eventos para que le ayude a planear su fiesta familiar.'},
#  {'titulo': 'Repugnante online',
#   'clasificacion': 'SAM13',
#   'duracion': '97 MIN',
#   'genero': 'DRAMA',
#   'año': '2014',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un oficial de policía drogadicto planea arruinar las posibilidades de ascenso de sus colegas por cualquier medio, incluyendo contar secretos y seducir a sus esposas. Basado en la novela de Irvine'},
#  {'titulo': 'Un paso adelante online',
#   'clasificacion': 'SAM13',
#   'duracion': '103 MIN',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2006',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Tyler Gage (Channing Tatum) creció en las duras calles de Baltimore. Un roce con la ley obliga a Tyler a realizar servicio comunitario en la Escuela de artes de Maryland de la ciudad. Allí conoce a'},
#  {'titulo': 'Dura verdad online',
#   'clasificacion': 'SAM13',
#   'duracion': '93 MIN',
#   'genero': 'ACCIÓN, MISTERIO/SUSPENSO',
#   'año': '2012',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Durante su viaje en velero por España, una familia entera es secuestrada. Ahora, un joven de Wall Street debe enfrentar a las personas responsables: agentes de inteligencia del gobierno que buscan'},
#  {'titulo': 'Día del atentado online',
#   'clasificacion': 'SAM16',
#   'duracion': '133 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2016',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'La historia del bombardeo de la maratón de Boston del 2013 y la búsqueda de personas en la ciudad para encontrar a los terroristas responsables.'},
#  {'titulo': 'John Wick 2: Un nuevo día para matar online',
#   'clasificacion': 'SAM16',
#   'duracion': '122 MIN',
#   'genero': 'ACCIÓN',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'En esta secuela del éxito de 2014, el legendario asesino John Wick (Keanu Reeves) se ve obligado a salir del retiro por un ex-asociado que planea obtener el control de un misterioso grupo'},
#  {'titulo': 'La reina online',
#   'clasificacion': 'SAM13',
#   'duracion': '103 MIN',
#   'genero': 'BIOGRÁFICA, DRAMA',
#   'año': '2006',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Hellen Mirren ganó el Oscar a Mejor Actriz en 2006 por su brillante retrato de la Reina Isabel cuando lidiaba con la trágica muerte de la Princesa Diana.'},
#  {'titulo': 'Pobres divas online',
#   'clasificacion': 'SAM13',
#   'duracion': '106 MIN',
#   'genero': 'ROMÁNTICA, COMEDIA',
#   'año': '2011',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Nora y Mary Domínguez, dos hermanas que llevan una vida fácil y llena de lujos en Beverly Hills, lo pierden todo cuando su padre muere súbitamente. Las hermanas van a vivir con su tía a Los Ángeles'},
#  {'titulo': 'Si no despierto online',
#   'clasificacion': 'SAM13',
#   'duracion': '98 MIN',
#   'genero': 'DRAMA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Samantha Kingston (Zoey Deutch), una preparatoriana a punto de graduarse, que lo tiene todo. El 12 de Febrero es sólo otro venturoso día en la vida de Sam hasta que se ve atascada reviviéndolo'},
#  {'titulo': 'La maldición de Blackwood online',
#   'clasificacion': 'SAM13',
#   'duracion': '96 MIN',
#   'genero': 'DRAMA, FANTASÍA',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cinco adolescentes emocionalmente frágiles son enviadas a Blackwood, una misteriosa escuela para niñas superdotadas y perturbadas.'},
#  {'titulo': 'El grito online',
#   'clasificacion': 'SAM13',
#   'duracion': '91 MIN',
#   'genero': 'SUSPENSO, MISTERIO/SUSPENSO',
#   'año': '2004',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Karen es una enfermera estadounidense que vive en Tokio y está expuesta a una misteriosa maldición sobrenatural. La maldición es un espíritu vengativo que posee a una persona en una rabia poderosa'},
#  {'titulo': 'Son como niños 2 online',
#   'clasificacion': 'SAM13',
#   'duracion': '100 MIN',
#   'genero': 'SECUELA, COMEDIA',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'La secuela de Son como niños. Después de mudarse con su familia de regreso a su ciudad natal para estar con sus amigos y sus hijos, Lenny, descubre que entre los antiguos y los nuevos'},
#  {'titulo': 'Lo que pasó recién online',
#   'clasificacion': 'SAM16',
#   'duracion': '103 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2008',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un desesperado productor de películas intenta revivir su carrera moribunda y mantener su dignidad mientras lucha por lograr realizar su película durante un lapso de dos semanas.'},
#  {'titulo': '¡Competencia en la cocina! online',
#   'clasificacion': 'ATP',
#   'duracion': '98 MIN',
#   'genero': 'COMEDIA, ROMÁNTICA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Una madre soltera que sueña con una vida mejor y ama cocinar encuentra el camino al éxito cuando su hijo la insribe en una competencia de gastronomía.'},
#  {'titulo': 'El Karate Kid online',
#   'clasificacion': 'ATP',
#   'duracion': '126 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '1984',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un adolescente aprende sobre la vida, la amistad y el coraje bajo la guía de un maestro de artes marciales.'},
#  {'titulo': 'Empire State el gran robo del Bronx online',
#   'clasificacion': 'SAM16',
#   'duracion': '94 MIN',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2013',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un guardia de seguridad es convencido por su imprudente mejor amigo de robar la compañía para la cual trabaja, junto a una violenta banda criminal y un duro detective en su camino...¿Podrán escaparse'},
#  {'titulo': 'Ali online',
#   'clasificacion': 'SAM16',
#   'duracion': '156 MIN',
#   'genero': 'BIOGRÁFICA, DRAMA',
#   'año': '2001',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Basada en la vida del tan controvertido, pero indiscutiblemente electrizante boxeador, Muhammad Ali.'},
#  {'titulo': 'Cubos online',
#   'clasificacion': 'SAM16',
#   'duracion': '90 MIN',
#   'genero': 'DRAMA, FANTASÍA',
#   'año': '1997',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un grupo de seis completos extraños, de personalidades y orígenes muy variados, son puestos involuntariamente en un laberinto interminable que contiene trampas mortales. Sin recordar cómo llegaron al'},
#  {'titulo': 'Rápido y fogoso online',
#   'clasificacion': 'SAM16',
#   'duracion': '109 MIN',
#   'genero': 'COMEDIA, ROMÁNTICA',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un adolescente desesperado por perder su virginidad convence a sus amigos de ir en un viaje por carretera con él para conocer a una chica que conoció en línea, pero el viaje pronto resulta en una'},
#  {'titulo': 'Crank: muerte anunciada online',
#   'clasificacion': 'SAM16',
#   'duracion': '87 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2006',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Hoy es el último día de la vida del asesino a sueldo Chev Chelios. Le suministraron un veneno que lo matará si permite que su corazón se estabilice a un ritmo normal. Para mantenerse con vida y'},
#  {'titulo': 'Al borde del abismo online',
#   'clasificacion': 'SAM13',
#   'duracion': '102 MIN',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2012',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un ex policía, recientemente liberado de prisión, está parado en la cornisa de un edificio, amenazando con saltar. Mientras tanto, un enorme robo de joyas se está llevando a cabo cerca ¿hay más en la'},
#  {'titulo': 'Triple X online',
#   'clasificacion': 'SAM13',
#   'duracion': '124 MIN',
#   'genero': 'ACCIÓN',
#   'año': '2002',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un atleta de deportes extremos, Xander Cage, es reclutado por el gobierno en una misión especial.'},
#  {'titulo': 'La maldición de la casa Winchester online',
#   'clasificacion': 'SAM13',
#   'duracion': '99 MIN',
#   'genero': 'BIOGRÁFICA, FANTASÍA',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El bebé y el marido (William Wirt Winchester) de Sarah Winchester, heredera de la compañía de rifles Winchester, mueren repentinamente. Debido a ello, cree estar maldita por toda la muerte causada por'},
#  {'titulo': 'Mamma Mia! online',
#   'clasificacion': 'ATP',
#   'duracion': '108 MIN',
#   'genero': 'MUSICAL, COMEDIA',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Donna, una madre independiente y soltera, dueña de un pequeño hotel en una idílica isla griega, está a punto de dejar que se marche Sophie, la hija a la que ha criado sola.'},
#  {'titulo': 'Hellraiser: Juicio online',
#   'clasificacion': 'SAM16',
#   'duracion': '81 MIN',
#   'genero': 'DE TERROR',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Tres detectives intentan resolver un asesinato diabólico que los arrastra a las profundidades del infierno en esta próxima edición de la clásica serie HELLRAISER.'},
#  {'titulo': 'La enfermera online',
#   'clasificacion': 'SAM16',
#   'duracion': '83 MIN',
#   'genero': 'ERÓTICA, DE TERROR',
#   'año': '2014',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Durante el día, la enfermera Abby Russell se ocupa con cariño de los pacientes de All Saints Memorial Hospital; durante la noche, merodea por los clubes nocturnos, seduciendo a hombres infieles a'},
#  {'titulo': 'El árbol de Navidad online',
#   'clasificacion': 'ATP',
#   'duracion': '87 MIN',
#   'genero': 'NAVIDEÑA, DRAMA',
#   'año': '2014',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Cuando la chica de la gran ciudad (Lacey Chabert) regresa para salvar la el vivero de árboles de su infancia, tal vez puede redescubrir más de lo que quería, incluyendo a su amor verdadero.'},
#  {'titulo': 'Dulce venganza online',
#   'clasificacion': 'SAM16',
#   'duracion': '108 MIN',
#   'genero': 'DE TERROR, MISTERIO/SUSPENSO',
#   'año': '2010',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Este remake del clásico de 1978 del mismo nombre, cuenta la historia de una mujer que es brutalmente violada y asaltada por cuatro hombres, sobrevive, y toma la ley en sus propias manos buscando'},
#  {'titulo': 'Una esposa de mentira online',
#   'clasificacion': 'SAM13',
#   'duracion': '116 MIN',
#   'genero': 'COMEDIA, ROMÁNTICA',
#   'año': '2011',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un hombre recurre a una mujer y a sus hijos para conquistar a la mujer de sus sueños.'},
#  {'titulo': 'Enemigo invisible online',
#   'clasificacion': 'SAM16',
#   'duracion': '102 MIN',
#   'genero': 'DRAMA, MISTERIO/SUSPENSO',
#   'año': '2016',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'La coronel Katherine Powell dirige una misión secreta de drones para capturar a un grupo de terroristas que vive en una casa de seguridad en Narobi, Kenia. La situación escala de nivel cuando el'},
#  {'titulo': 'Divergente online',
#   'clasificacion': 'SAM13',
#   'duracion': '139 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'En el futuro, una adolescente aprende que es una "Divergente". Cuando se entera del complot de un malvado líder para asesinar a todos los divergentes se embarca en una búsqueda frenética para saber la'},
#  {'titulo': 'Si Solo Pudiera Imaginar online',
#   'clasificacion': 'ATP',
#   'duracion': '110 MIN',
#   'genero': 'DRAMA, FAMILIAR',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Bart Millard es el líder de la banda cristiana MercyMe, que pierde a su padre por un cáncer. Este trágico suceso le inspira a escribir una canción que tiene gran éxito llamada I Can Only Imagine y en'},
#  {'titulo': 'The Grudge 2 online',
#   'clasificacion': 'SAM13',
#   'duracion': '102 MIN',
#   'genero': 'DE TERROR, SUSPENSO',
#   'año': '2006',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Una joven mujer (Amber Tamblyn) descubre una terrible maldición mientras busca a su hermana (Sarah Michelle Gellar) desaparecida en Tokio.'},
#  {'titulo': 'Mi nombre es Tsotsi online',
#   'clasificacion': 'SAM16',
#   'duracion': '94 MIN',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2005',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un criminal convertido en asesino se da cuenta de que la mujer que asesinó dejó un bebé en el asiento trasero de su coche, y pronto se vuelve más apegado a él de lo que nunca pensó posible.'},
#  {'titulo': 'El último cazador de brujas online',
#   'clasificacion': 'SAM13',
#   'duracion': '106 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El último cazador de brujas es la única barrera entre la humanidad y las fuerzas combinadas de las más terribles brujas de la historia.'},
#  {'titulo': 'Crepúsculo La Saga: Amanecer - Parte 1 online',
#   'clasificacion': 'SAM13',
#   'duracion': '117 MIN',
#   'genero': 'DE AVENTURAS, DRAMA',
#   'año': '2011',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Drama de fantasía protagonizada por Robert Pattinson y Kristen Stewart. Después de regresar de su Luna de miel, Bella y Edward se sorprenden al descubrir que están esperando un bebé. Las cosas pronto'},
#  {'titulo': 'Crepúsculo, la saga: Eclipse online',
#   'clasificacion': 'SAM13',
#   'duracion': '123 MIN',
#   'genero': 'DE AVENTURAS, DRAMA',
#   'año': '2010',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Mientras una serie de misteriosos asesinatos se apodera de Seattle, Bella, cuya graduación de secundaria se acerca rápidamente, se ve obligada a elegir entre su amor por el vampiro Edward y su amistad'},
#  {'titulo': 'El grito 3 online',
#   'clasificacion': 'SAM16',
#   'duracion': '90 MIN',
#   'genero': 'DE TERROR, MISTERIO',
#   'año': '2009',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un doctor (Shawnee Smith) necesita la ayuda de una misteriosa mujer japonesa para combatir a dos fantasmas vengativos.'},
#  {'titulo': 'El lado oscuro del deseo online',
#   'clasificacion': 'SAM16',
#   'duracion': '99 MIN',
#   'genero': 'MISTERIO/SUSPENSO',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Evan es un hombre casado cuya mujer e hijos están de viaje. Una noche lluviosa acoge a dos chicas que, aunque al principio se muestre reacio, lo seducen. Lo que todavía no sabe son los horribles'},
#  {'titulo': 'Rudo y Cursi : La vida es un volado online',
#   'clasificacion': 'SAM16',
#   'duracion': '101 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Los hermanos Beto (Diego Luna) y Tato (Gael García Bernal) Verdusco trabajan en un rancho platanero y juegan futbol en el equipo de su pueblo.'},
#  {'titulo': 'De Tyler Perry: ¿Por qué nos casamos? online',
#   'clasificacion': 'SAM13',
#   'duracion': '118 MIN',
#   'genero': 'DRAMA',
#   'año': '2007',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un grupo de amigos universitarios casados van a Colorado para su reunión anual de una semana. Superficialmente, parece que será como todas las reuniones anteriores que han tenido a lo largo de los'},
#  {'titulo': 'Sicario online',
#   'clasificacion': 'SAM16',
#   'duracion': '121 MIN',
#   'genero': 'ACCIÓN, SUSPENSO',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'En el área fronteriza y anárquica que se extiende entre los Estados Unidos y México, una agente idealista del FBI es reclutada por un funcionario gubernamental élite para ayudar en la creciente guerra'},
#  {'titulo': 'Escondida online',
#   'clasificacion': 'SAM13',
#   'duracion': '88 MIN',
#   'genero': 'DRAMA, MISTERIO/SUSPENSO',
#   'año': '2011',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Una detective de Boston investiga los cuerpos momificados de seis mujeres.'},
#  {'titulo': 'Pasión inocente online',
#   'clasificacion': 'SAM16',
#   'duracion': '97 MIN',
#   'genero': 'DRAMA, ROMÁNTICA',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Megan, una esposa y madre, decide que la familia debe acoger a la estudiante de intercambio, Sophie.'},
#  {'titulo': 'Jigsaw: El juego continúa online',
#   'clasificacion': 'SAM16',
#   'duracion': '91 MIN',
#   'genero': 'DE TERROR',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cadáveres se han estado apareciendo por toda la ciudad. Conforme la investigación avanza, las evidencias indican hacia un hombre: John Kramer. Pero ¿cómo puede ser esto? El hombre conocido como Jigsaw'},
#  {'titulo': 'La última puerta online',
#   'clasificacion': 'SAM16',
#   'duracion': '133 MIN',
#   'genero': 'SOBRENATURAL, ACCIÓN',
#   'año': '1999',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Johnny Depp es contratado por un fiel satánico que se hace pasar por un erudito de la demonología para localizar dos escasos volúmenes de una invocación satánica.'},
#  {'titulo': 'Posdata, te amo online',
#   'clasificacion': 'SAM13',
#   'duracion': '125 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2007',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Una viuda (Hilary Swank) apenada encuentra una serie de mensajes que le dejó su marido fallecido para ayudarle a disminuir su dolor y alentarla a iniciar una nueva vida por sí misma.'},
#  {'titulo': 'Jerry Maguire: Amor y desafio online',
#   'clasificacion': 'SAM13',
#   'duracion': '138 MIN',
#   'genero': 'COMEDIA ROMÁNTICA, ROMÁNTICA',
#   'año': '1996',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Tom Cruise hace su mejor actuación hasta la fecha (Neil Rosen, NY-1) como representante deportivo que de repente descubre sus escrúpulos y en consecuencia pierde su trabajo.'},
#  {'titulo': 'Extraordinario online',
#   'clasificacion': 'ATP',
#   'duracion': '113 MIN',
#   'genero': 'DRAMA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Tanto su familia como sus compañeros de clases y la comunidad en general luchan por encontrar la compasión y la aceptación, el extraordinario viaje de Auggie los unirá y les probará que no puedes'},
#  {'titulo': 'Xxx 2: Estado de emergencia online',
#   'clasificacion': 'SAM16',
#   'duracion': '100 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2005',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'En esta secuela llena de acción del éxito de taquilla xXx, Ice Cube interpreta a Darius Stone, un alborotador que busca emoción cuyos antecedentes penales y su obsesión por los deportes extremos lo'},
#  {'titulo': 'Elizabeth: La edad de oro online',
#   'clasificacion': 'SAM13',
#   'duracion': '114 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2007',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cate Blanchett y Geoffrey Rush protagonizan esta emocionante historia de la lucha de una mujer para controlar el amor, aplastar a sus enemigos y consolidarse en el trono de Inglaterra.'},
#  {'titulo': 'RED: Retirados Extremadamente Duros online',
#   'clasificacion': 'SAM13',
#   'duracion': '111 MIN',
#   'genero': 'ACCIÓN, COMEDIA',
#   'año': '2010',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuando un agente retirado de la CIA es el objetivo de un asesino mortal, llama a sus viejos amigos del trabajo en un intento de conocer la verdad mientras se mantiene alejado de las garras del'},
#  {'titulo': 'Crímenes ocultos online',
#   'clasificacion': 'SAM16',
#   'duracion': '137 MIN',
#   'genero': 'CRIMEN, DRAMA',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un agente soviético caído en desgracia descubre una conexión entre una serie de asesinatos infantiles y el líder de un partido. Those who seek the truth will be silenced. Basada en una novela de Tom'},
#  {'titulo': 'Whiplash: Música y obsesión online',
#   'clasificacion': 'SAM16',
#   'duracion': '106 MIN',
#   'genero': 'MÚSICA, DRAMA',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El objetivo de Andrew Neiman, un joven y ambicioso baterista de jazz, es triunfar en el elitista Conservatorio de Música de la Costa Este en el que estudia. Marcado por el fracaso de la carrera'},
#  {'titulo': 'Los juegos del hambre: Sinsajo - Parte 1 online',
#   'clasificacion': 'SAM13',
#   'duracion': '122 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'El fenómeno mundial continúa. Katniss (Jennifer Lawrence) sobrevivió y destruyó los Juegos del Hambre, y ahora se levanta con el Distrito 13 para luchar contra el presidente Snow (Donald Sutherland).'},
#  {'titulo': 'Spider-Man: De regreso a casa online',
#   'clasificacion': 'SAM13',
#   'duracion': '133 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un joven Peter Parker/Hombre Araña comienza a navegar la nueva identidad encontrada como el superhéroe lanzador de la web.'},
#  {'titulo': 'De Tyler Perry: El club de las madres solteras online',
#   'clasificacion': 'SAM13',
#   'duracion': '111 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cinco madres solteras en problemas dejan de lado sus diferencias para formar un grupo de apoyo, hallan inspiración y humor en su nueva hermandad y se ayudan mutuamente para superar los obstáculos que'},
#  {'titulo': 'Cuenta regresiva online',
#   'clasificacion': 'SAM13',
#   'duracion': '121 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2009',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un maestro abre una cápsula del tiempo que ha sido desenterrada en la escuela primaria de su hijo, en ella hay algunas predicciones escalofriantes, algunas que ya han ocurrido y otras que están a'},
#  {'titulo': 'Siniestro online',
#   'clasificacion': 'SAM16',
#   'duracion': '110 MIN',
#   'genero': 'DE TERROR, MISTERIO',
#   'año': '2012',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un autor se muda con su familia a una casa con un pasado oscuro con la esperanza de encontrar inspiración. Sin embargo, después de descubrir un conjunto de cintas de vídeo escalofriantes en la casa,'},
#  {'titulo': 'Apariciones online',
#   'clasificacion': 'SAM16',
#   'duracion': '90 MIN',
#   'genero': 'DRAMA, HISTÓRICA',
#   'año': '2005',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Extraños y aterradores sucesos rodean a una familia (Donald Sutherland, Sissy Spacek, Rachel Hurd-Wood) en el estado de Tennessee de 1817 luego de que un ciudadano maldijera al padre. Possession knows'},
#  {'titulo': 'Crepúsculo la saga: Luna Nueva online',
#   'clasificacion': 'SAM13',
#   'duracion': '130 MIN',
#   'genero': 'DE AVENTURAS, DRAMA',
#   'año': '2009',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'A Bella se le parte el corazón cuando la familia Cullen decide mudarse para poner fin a su relación con el vampiro Edward. Ella busca consuelo en su amigo Jacob, y comienza a preguntarse si podrían'},
#  {'titulo': 'El Príncipe y yo online',
#   'clasificacion': 'ATP',
#   'duracion': '110 MIN',
#   'genero': 'COMEDIA ROMÁNTICA, ADOLESCENTE',
#   'año': '2004',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Paige es una estudiante de medicina brillante de un pueblo rural con grandes planes para su futuro. Sin embargo, estos planes quedan en un segundo plano cuando conoce a Eddie, un estudiante de'},
#  {'titulo': 'Divergente la serie: Insurgente online',
#   'clasificacion': 'SAM13',
#   'duracion': '118 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Los fugitivos Tris y Four buscan aliados y respuestas entre las ruinas de Chicago mientras tratan de evadir desesperadamente a Jeanine, líder de los Eruditos. Basada en la novela de Veronica Roth'},
#  {'titulo': 'Punto ciego online',
#   'clasificacion': 'SAM16',
#   'duracion': '95 MIN',
#   'genero': 'COMEDIA, DRAMA',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Los amigos de toda la vida Daveed Diggs y Rafael Casal coescribieron y protagonizaron esta entretenida historia sobre las interacciones de las razas y clases en una Oakland en rápido crecimiento.'},
#  {'titulo': 'Una vida por delante online',
#   'clasificacion': 'SAM13',
#   'duracion': '107 MIN',
#   'genero': 'DRAMA, FAMILIAR',
#   'año': '2005',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Un ranchero (Robert Redford) de Wyoming le da refugio a su sufrida nuera (Jennifer Lopez), cuyas heridas tardan un buen tiempo en sanar.'},
#  {'titulo': 'Campamento del terror online',
#   'clasificacion': 'SAM13',
#   'duracion': '84 MIN',
#   'genero': 'DE TERROR',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuatro jóvenes estadounidenses se apuntan como monitores en un campamento de verano en Europa. Al llegar, una extraña infección, que causa furia extrema, sumerge al grupo en una espiral de terror y'},
#  {'titulo': 'Casino online',
#   'clasificacion': 'SAM16',
#   'duracion': '178 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '1995',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Esta historia se desarrolla en Las Vegas, en 1973, y está basada en hechos sobre la operación de un casino multimillonario de la mafia donde las fortunas y las vidas se creaban y se perdían.'},
#  {'titulo': 'Maria Antonieta La Reina Adolescente online',
#   'clasificacion': 'SAM13',
#   'duracion': '122 MIN',
#   'genero': 'DRAMA',
#   'año': '2006',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'La historia de Marie-Antoinette, una ingenua austriaca de 14 años que se casó con Luís XVI sin estar preparada para los problemas políticos de ser la Reina de Francia durante la Revolución Francesa.'},
#  {'titulo': 'Llámame Por Tu Nombre online',
#   'clasificacion': 'SAM16',
#   'duracion': '131 MIN',
#   'genero': 'DRAMA, LITERARIA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'A mediados del esplendoroso verano de 1980 en Italia, Elio y Oliver descubren el maravilloso despertar del deseo que cambiara sus vidas por siempre.'},
#  {'titulo': 'Dune online',
#   'clasificacion': 'SAM13',
#   'duracion': '136 MIN',
#   'genero': 'DE CULTO, DRAMA',
#   'año': '1984',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Ésta es la saga del guerrero Intergaláctico Paul Atreides y su ascenso mesiánico para conducir a su pueblo en su lucha por la supervivencia.'},
#  {'titulo': 'Jumanji: En la selva online',
#   'clasificacion': 'SAM13',
#   'duracion': '119 MIN',
#   'genero': 'COMEDIA, FAMILIAR',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuatro adolescentes en detención descubren una vieja consola de videojuegos con un juego del que nunca han escuchado. Cuando deciden jugar, son inmediatamente succionador hacia la jungla de Jumanji,'},
#  {'titulo': 'Father Figures online',
#   'clasificacion': 'SAM16',
#   'duracion': '112 MIN',
#   'genero': 'COMEDIA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Dos hermanos mellizos crecieron pensando que su padre había muerto, pero descubren que está vivo y emprenden un viaje para encontrarlo. No será sencillo, ya que su madre se acostó con muchos hombres'},
#  {'titulo': 'Los juegos del hambre: En llamas online',
#   'clasificacion': 'SAM13',
#   'duracion': '146 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Katniss Everdeen ha regresado a casa a salvo después de ganar los 74º juegos anuales del Hambre. Siente que una rebelión se avecina, pero el Capitolio todavía está en control, ya que los Próximos'},
#  {'titulo': 'Los juegos del hambre: Sinsajo - El final online',
#   'clasificacion': 'SAM13',
#   'duracion': '136 MIN',
#   'genero': 'ACCIÓN, CIENCIA FICCIÓN',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Jennifer Lawrence interpreta a Katniss Everdeen, que comenzó su viaje luchando por sobrevivir a los despiadados Juegos del Hambre, y dirigió la rebelión contra el tiránico presidente de Panem (Donald'},
#  {'titulo': 'De Tyler Perry: Las niñas de papá online',
#   'clasificacion': 'SAM13',
#   'duracion': '100 MIN',
#   'genero': 'DRAMA, ROMÁNTICA',
#   'año': '2007',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Una historia opuesta a la de Cenicienta, en la que una exitosa abogada (Union) se enamora de un mecánico (Elba) con problemas financieros y padre soltero de tres niñas.'},
#  {'titulo': 'La cabaña online',
#   'clasificacion': 'SAM13',
#   'duracion': '132 MIN',
#   'genero': 'DRAMA',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'A raíz de una tragedia personal, Mackenzie Allen Phillips recibe una nota misteriosa invitándolo a “La cabaña.” Mack acude y se ve envuelto en la catarsis de redescubrir la verdad sobre el amor, la'},
#  {'titulo': 'El Justiciero online',
#   'clasificacion': 'SAM16',
#   'duracion': '131 MIN',
#   'genero': 'ACCIÓN, DRAMA',
#   'año': '2014',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un ex-comando sale del retiro y pone sus habilidades especiales a trabajar para rescatar a una chica que está bajo el control de unos criminales rusos. What do you see when you look at me? Basada en'},
#  {'titulo': '47 Ronin online',
#   'clasificacion': 'SAM13',
#   'duracion': '118 MIN',
#   'genero': 'ACCIÓN, DE AVENTURAS',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Después de que un traicionero caudillo mate a su señor y los destierre, 47 intrépidos samuráis juran vengarse y recobrar el honor de los suyos.'},
#  {'titulo': 'El legado online',
#   'clasificacion': 'SAM13',
#   'duracion': '102 MIN',
#   'genero': 'ACCIÓN, CIENCIA FICCIÓN',
#   'año': '2018',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un exconvicto recientemente liberado y su hermano menor, adoptivo, se ven obligados a huir. Al ser perseguidos por un criminal vengativo, los federales y un grupo de soldados de otro mundo,'},
#  {'titulo': 'Rendirse jamás online',
#   'clasificacion': 'SAM13',
#   'duracion': '113 MIN',
#   'genero': 'ACCIÓN, CRIMEN',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Un adolescente rebelde ingresa a una nueva escuela, donde se ve envuelto en la escena de la lucha clandestina. Ayudado por un especialista en artes marciales mixtas, se prepara para asumir su mayor'},
#  {'titulo': 'Escándalo Americano online',
#   'clasificacion': 'SAM16',
#   'duracion': '138 MIN',
#   'genero': 'COMEDIA, CRIMEN',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Thriller político ambientado en los años 70 sobre un agente del FBI que investiga un caso en el que algunos miembros del Congreso aparecen implicados en un delito.'},
#  {'titulo': 'Lugares oscuros online',
#   'clasificacion': 'SAM16',
#   'duracion': '113 MIN',
#   'genero': 'CRIMEN, MISTERIO',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Charlize Theron, Nicholas Hoult, Cholë Grace Moretz y Christina Hendricks protagonizan este thriller de misterio, basado en la novela de Gillian Flynn (Perdida).'},
#  {'titulo': 'El duende 2 online',
#   'clasificacion': 'SAM16',
#   'duracion': '85 MIN',
#   'genero': 'COMEDIA, FANTASÍA',
#   'año': '1994',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Hace mil años, un duende malvado se frustra al intentar atrapar a una joven novia. Ahora, en 1994 en Los Ángeles, el duende está decidido a tomar a la hermosa descendiente de la mujer como su novia y'},
#  {'titulo': 'Plan de escape online',
#   'clasificacion': 'SAM16',
#   'duracion': '115 MIN',
#   'genero': 'ACCIÓN',
#   'año': '2013',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Ray Breslin, una de las principales autoridades del mundo en materia de seguridad estructural, acepta asumir un trabajo poco ortodoxo: salir de una instalación ultra secreta y de alta tecnología'},
#  {'titulo': 'Grey Lady online',
#   'clasificacion': 'SAM16',
#   'duracion': '109 MIN',
#   'genero': 'MISTERIO/SUSPENSO',
#   'año': '2017',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Después de que su compañera policía y amante, fuera asesinada en Boston, el detective de homicidios James Doyle (Eric Dane) sigue una pista puesta en las últimas palabras de ella hasta la remota isla'},
#  {'titulo': 'Traficantes por error online',
#   'clasificacion': 'SAM16',
#   'duracion': '84 MIN',
#   'genero': 'ACCIÓN, COMEDIA',
#   'año': '2009',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Donald Faison protagoniza como un repartidor desafortunado que se encuentra en el centro de un negocio de drogas que salió horriblemente mal en Traficantes por Error, una comedia de acción estruendosa'},
#  {'titulo': 'La Cumbre Escarlata online',
#   'clasificacion': 'SAM16',
#   'duracion': '118 MIN',
#   'genero': 'DRAMA, DE TERROR',
#   'año': '2015',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Cuando un extraño seductor le roba el corazón, una joven mujer se deja llevar hasta una casa en la cima de una montaña de arcilla color rojo sangre, un lugar lleno de secretos que la perseguirán por'},
#  {'titulo': 'Oscura seducción online',
#   'clasificacion': 'SAM16',
#   'duracion': '89 MIN',
#   'genero': 'ROMÁNTICA',
#   'año': '2011',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Una cirujana plástica exitosa se embarca en una aventura apasionada con un enfermero, solo para descubrir el lado oscuro de su personalidad que alcanza niveles aterradores cuando ella se ve obligada a'},
#  {'titulo': 'Querido Santa Secreto online',
#   'clasificacion': 'ATP',
#   'duracion': '89 MIN',
#   'genero': 'NAVIDEÑA, DRAMA',
#   'año': '2013',
#   'tipo_de_audio': 'ESTÉREO',
#   'sinopsis': 'Tatyana Ali estelariza en esta película llena de estrellas, incluyendo a Jordin Sparks, Ernie Hudson y Della Reese. ¡Es un reconfortante romance navideño!'},
#  {'titulo': 'Crepúsculo online',
#   'clasificacion': 'SAM13',
#   'duracion': '121 MIN',
#   'genero': 'DRAMA, FANTASÍA',
#   'año': '2008',
#   'tipo_de_audio': 'SONIDO ENVOLVENTE 5.1',
#   'sinopsis': 'Una adolescente con problemas se muda con su padre a un pequeño pueblo aislado. Ella se enamora de un misterioso solitario con un secreto impactante, ¿podría tener algo que ver con los asesinatos'}]

# %%
#Transform list to pandas dataframe.
df = pd.DataFrame(lista_peliculas)

# %%
df
# Out:
#                                 titulo clasificacion duracion  \
# 0    Una Navidad a la moda real online           ATP   86 MIN
# 1           A conseguir trabajo online         SAM13   82 MIN
# 2    La novia de mi mejor amigo online         SAM16  100 MIN
# 3                Decisión final online         SAM13  109 MIN
# 4                          2012 online         SAM13  157 MIN
# ..                                 ...           ...      ...
# 105       Traficantes por error online         SAM16   84 MIN
# 106         La Cumbre Escarlata online         SAM16  118 MIN
# 107            Oscura seducción online         SAM16   89 MIN
# 108       Querido Santa Secreto online           ATP   89 MIN
# 109                  Crepúsculo online         SAM13  121 MIN
#
#                          genero   año          tipo_de_audio  \
# 0             NAVIDEÑA, COMEDIA  2018  SONIDO ENVOLVENTE 5.1
# 1    COMEDIA, COMEDIA ROMÁNTICA  2016  SONIDO ENVOLVENTE 5.1
# 2            COMEDIA, ROMÁNTICA  2008  SONIDO ENVOLVENTE 5.1
# 3               DRAMA, DEPORTES  2014                ESTÉREO
# 4                 ACCIÓN, DRAMA  2009  SONIDO ENVOLVENTE 5.1
# ..                          ...   ...                    ...
# 105             ACCIÓN, COMEDIA  2009                ESTÉREO
# 106            DRAMA, DE TERROR  2015  SONIDO ENVOLVENTE 5.1
# 107                   ROMÁNTICA  2011  SONIDO ENVOLVENTE 5.1
# 108             NAVIDEÑA, DRAMA  2013                ESTÉREO
# 109             DRAMA, FANTASÍA  2008  SONIDO ENVOLVENTE 5.1
#
#                                               sinopsis
# 0    Kristin Cooper, la guapa y talentosa asistente...
# 1    Cuando Will se queda sin trabajo y a Jillian l...
# 2    Tank (Dane Cook) se enfrenta a la mayor prueba...
# 3    En el día del Draft de la NFL, el gerente gene...
# 4    El mundo se enfrenta a una catástrofe de propo...
# ..                                                 ...
# 105  Donald Faison protagoniza como un repartidor d...
# 106  Cuando un extraño seductor le roba el corazón,...
# 107  Una cirujana plástica exitosa se embarca en un...
# 108  Tatyana Ali estelariza en esta película llena ...
# 109  Una adolescente con problemas se muda con su p...
#
# [110 rows x 7 columns]

# %%
#Save it to csv file
df.to_csv('datasets/peliculas.csv')

# %%
#Save it to json file
df.to_json('datasets/pelicula.json')

# %%
driver.quit()
